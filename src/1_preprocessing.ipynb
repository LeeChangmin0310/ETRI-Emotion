# %% [markdown]
# # 🎯 Emotion-Domain Classification with PyCaret AutoML (`domain_EI`, 4 classes)
#
# This notebook builds ML classifiers to predict the **emotion-intelligence domain** (`domain_EI`) with four labels
# (HAHV · HALV · LALV · LAHV  →  encoded as 0-3) using **PyCaret 3**.
#
# ---
#
# ## 🧩 Objectives
#
# | Item | Details |
# |------|---------|
# | **Feature sets** | 4 configurations (score_EI / group_EI included or removed) |
# | **Scaling options** | `none`, `standard`, `minmax` |
# | **Model family** | CatBoost · XGBoost · Random Forest · Extra Trees · Logistic Regression · Naive Bayes · SVM · K-NN · QDA |
# | **Total runs** | **12** (4 feature configs × 3 scalers) |
# | **Validation** | Stratified **3-fold CV** inside PyCaret + **20 % hold-out** |
# | **Artifacts** | PNG plots (AUC, confusion matrix, feature importance) + CSV summaries |
#
# ---
#
# ## 🛠️ Pipeline Overview
#
# | Step | Description |
# |------|-------------|
# | **1 — Split** | Apply feature-exclusion rules, then stratified 80 / 20 train-test split |
# | **2 — Scaling** | Transform numeric features with the chosen scaler (`none` / `StandardScaler` / `MinMaxScaler`) |
# | **3 — AutoML** | `compare_models()` evaluates the candidate models via CV and returns the best estimator |
# | **4 — Hold-out Evaluation** | Predict on the reserved test set; save confusion-matrix & AUC plots |
# | **5 — Result Logging** | Collect CV AUC / Accuracy and hold-out Accuracy for each run into a master CSV |
#
# ---
#
# ## 📂 Output Artifacts
#
# | File / Folder | Contents |
# |---------------|----------|
# | **`overall_results.csv`** | One-row summary per run (feature cfg · scaler · chosen model · metrics) |
# | **`leaderboard_cfg*_*.csv`** | Full PyCaret leaderboard (all models, CV statistics) |
# | **`CM_/`, `AUC_/`, `FI_/`** | Confusion-matrix, AUC curve and feature-importance PNGs named by run tag |
# | *(optional)* `best_models.pkl` | Serialized best estimators via `joblib.dump()` |
#
# ---
#
# ## 🔧 Requirements
#
# * **PyCaret 3.x** (classification module)
# * `scikit-learn`, `pandas`, `numpy`, `matplotlib`, `tqdm`
# * CatBoost & XGBoost are pulled automatically with the full PyCaret install
#
# > **Note**
# > * All stimulus-related (`Arousal`, `Valence`, etc.) and subjective self-report variables are **permanently excluded** from the feature space.
# > * The four feature configurations are designed to measure the impact of **EI score** (`score_EI`) and **EI group label** (`group_EI`) on model performance.
# > * GPU acceleration, SHAP explanations and 5-fold CV are **not** used in the current pipeline; they can be added later if needed.

# %% [markdown]
# ## Import Libraries

# %%
# ---------------------------------------------------------------
#  ❖  CONFIG & PREP
# ---------------------------------------------------------------
import os, sys, types, re, joblib, warnings

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, roc_auc_score
from sklearn.ensemble import ExtraTreesClassifier          # used for FS
from pycaret.classification import *
warnings.filterwarnings("ignore", category=UserWarning)

from scipy.stats import zscore
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %% [markdown]
# ## Step 0: Define Save Paths
#
# We define clean, relative paths for all outputs such as feature importance plots, evaluation plots, and CSV results.

# %%
# Base directory: project root (current notebook folder)
ROOT_PATH = os.getcwd()
RES_PATH = os.path.join(ROOT_PATH, '../res')

# DATA
DATA_PATH = os.path.join(os.getcwd(), '../data/')
EXCEL_PATH = "../data/ETRI_cardiac.xlsx"
CSV_PATH = "../data/ETRI_cardiac.csv"
DF_PATH = "../data/updated_data_multi.csv"
ARSL_PATH = "../data/updated_data_ArslBC.csv"
VLNC_PATH = "../data/updated_data_VlncBC.csv"

# Define subfolders for saving results
RES_MULTI_PATH = os.path.join(RES_PATH, 'multi')
FI_MULTI_PATH   = os.path.join(RES_MULTI_PATH, 'FI_plots')      # Feature Importance
CM_MULTI_PATH   = os.path.join(RES_MULTI_PATH, 'CM_plots')      # Confusion Matrix
AUC_MULTI_PATH  = os.path.join(RES_MULTI_PATH, 'AUC_plots')     # AUC Curves
SHAP_MULTI_PATH = os.path.join(RES_MULTI_PATH, 'SHAP_plots')    # SHAP Plots
RES_CSV_MULTI_PATH  = os.path.join(RES_MULTI_PATH, 'results_csv')   # CSV files

RES_ARSL_PATH = os.path.join(RES_PATH, 'ArslBC')
FI_ARSL_PATH   = os.path.join(RES_ARSL_PATH, 'FI_plots')      # Feature Importance
CM_ARSL_PATH   = os.path.join(RES_ARSL_PATH, 'CM_plots')      # Confusion Matrix
AUC_ARSL_PATH  = os.path.join(RES_ARSL_PATH, 'AUC_plots')     # AUC Curves
SHAP_ARSL_PATH = os.path.join(RES_ARSL_PATH, 'SHAP_plots')    # SHAP Plots
RES_CSV_ARSL_PATH  = os.path.join(RES_ARSL_PATH, 'results_csv')   # CSV files

RES_VLNC_PATH = os.path.join(RES_PATH, 'VlncBC')
FI_VLNC_PATH   = os.path.join(RES_VLNC_PATH, 'FI_plots')      # Feature Importance
CM_VLNC_PATH   = os.path.join(RES_VLNC_PATH, 'CM_plots')      # Confusion Matrix
AUC_VLNC_PATH  = os.path.join(RES_VLNC_PATH, 'AUC_plots')     # AUC Curves
SHAP_VLNC_PATH = os.path.join(RES_VLNC_PATH, 'SHAP_plots')    # SHAP Plots
RES_CSV_VLNC_PATH  = os.path.join(RES_VLNC_PATH, 'results_csv')   # CSV files


# Create directories if they don't exist
for path in [RES_PATH, RES_MULTI_PATH, FI_MULTI_PATH, CM_MULTI_PATH, AUC_MULTI_PATH, SHAP_MULTI_PATH, RES_CSV_MULTI_PATH,
             RES_ARSL_PATH, FI_ARSL_PATH, CM_ARSL_PATH, AUC_ARSL_PATH, SHAP_ARSL_PATH, RES_CSV_ARSL_PATH,
             RES_VLNC_PATH, FI_VLNC_PATH, CM_VLNC_PATH, AUC_VLNC_PATH, SHAP_VLNC_PATH, RES_CSV_VLNC_PATH]:
    os.makedirs(path, exist_ok=True)

# %%
df_multi = pd.read_csv(DF_PATH)
df_multi.head()
# Out:
#          name  year  score_EI  domain_EI  trainnig  group_EI  자극_Arousal  \
# 0  subj_01_00  2021       400          0         0         0           1
# 1  subj_01_01  2021       400          1         0         0           1
# 2  subj_01_02  2021       400          3         0         0           0
# 3  subj_01_03  2021       400          2         0         0           0
# 4  subj_02_00  2021       450          0         0         0           1
#
#    자극_Valence  Arousal  Valence  ...  VLF/HF_autocorr  LF/HF_autocorr  \
# 0           1        4        5  ...        -0.567119       -0.991761
# 1           0        6        4  ...        -2.854562       -1.532805
# 2           1        3        6  ...        -1.375726       -1.030548
# 3           0        4        4  ...        -0.198272        0.921968
# 4           1        6        7  ...         0.469754        0.216407
#
#    tPow_autocorr  dPow_autocorr  dHz_autocorr  pPow_autocorr  pHz_autocorr  \
# 0       4.761754      -0.106286     -0.597611      -0.177651     -1.020465
# 1      -4.013737      13.465573     -1.486156       0.136173     -0.504705
# 2       0.056760      -1.111399     -1.126756      -0.961825     -1.626310
# 3      -2.812514       7.058668     -0.880433      -0.866042     -0.602454
# 4       0.900575       0.121397      0.023057      -0.702703     -0.874824
#
#    CohRatio_autocorr  RSA_autocorr  dHz_diff_autocorr
# 0          -1.087973      1.085212          -0.595462
# 1          -0.481968      0.855739          -1.486156
# 2          -1.110674     -0.670813          -1.127433
# 3          -1.700471      0.168826          -0.880433
# 4           0.579896     -0.289846           0.023057
#
# [5 rows x 100 columns]

# %%
df_multi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 100 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               180 non-null    object
#  1   year               180 non-null    int64
#  2   score_EI           180 non-null    int64
#  3   domain_EI          180 non-null    int64
#  4   trainnig           180 non-null    int64
#  5   group_EI           180 non-null    int64
#  6   자극_Arousal         180 non-null    int64
#  7   자극_Valence         180 non-null    int64
#  8   Arousal            180 non-null    int64
#  9   Valence            180 non-null    int64
#  10  Subj_AR            180 non-null    int64
#  11  Subj_PN            180 non-null    int64
#  12  BPM                180 non-null    float64
#  13  SDNN               180 non-null    float64
#  14  rMSSD              180 non-null    float64
#  15  VLF                180 non-null    float64
#  16  LF                 180 non-null    float64
#  17  HF                 180 non-null    float64
#  18  VLFp               180 non-null    float64
#  19  LFp                180 non-null    float64
#  20  HFp                180 non-null    float64
#  21  lnVLF              180 non-null    float64
#  22  lnLF               180 non-null    float64
#  23  lnHF               180 non-null    float64
#  24  VLF/HF             180 non-null    float64
#  25  LF/HF              180 non-null    float64
#  26  tPow               180 non-null    float64
#  27  dPow               180 non-null    float64
#  28  dHz                180 non-null    float64
#  29  pPow               180 non-null    float64
#  30  pHz                180 non-null    float64
#  31  CohRatio           180 non-null    float64
#  32  RSA_PB             180 non-null    float64
#  33  tpow_diff          180 non-null    float64
#  34  BPM_var            180 non-null    float64
#  35  SDNN_var           180 non-null    float64
#  36  rMSSD_var          180 non-null    float64
#  37  VLF_var            180 non-null    float64
#  38  LF_var             180 non-null    float64
#  39  HF_var             180 non-null    float64
#  40  VLFp_var           180 non-null    float64
#  41  LFp_var            180 non-null    float64
#  42  HFp_var            180 non-null    float64
#  43  lnVLF_var          180 non-null    float64
#  44  lnLF_var           180 non-null    float64
#  45  lnHF_var           180 non-null    float64
#  46  VLF/HF_var         180 non-null    float64
#  47  LF/HF_var          180 non-null    float64
#  48  tPow_var           180 non-null    float64
#  49  dPow_var           180 non-null    float64
#  50  dHz_var            180 non-null    float64
#  51  pPow_var           180 non-null    float64
#  52  pHz_var            180 non-null    float64
#  53  CohRatio_var       180 non-null    float64
#  54  RSA_var            180 non-null    float64
#  55  dHz_diff_var       180 non-null    float64
#  56  BPM_mssd           180 non-null    float64
#  57  SDNN_mssd          180 non-null    float64
#  58  rMSSD_mssd         180 non-null    float64
#  59  VLF_mssd           180 non-null    float64
#  60  LF_mssd            180 non-null    float64
#  61  HF_mssd            180 non-null    float64
#  62  VLFp_mssd          180 non-null    float64
#  63  LFp_mssd           180 non-null    float64
#  64  HFp_mssd           180 non-null    float64
#  65  lnVLF_mssd         180 non-null    float64
#  66  lnLF_mssd          180 non-null    float64
#  67  lnHF_mssd          180 non-null    float64
#  68  VLF/HF_mssd        180 non-null    float64
#  69  LF/HF_mssd         180 non-null    float64
#  70  tPow_mssd          180 non-null    float64
#  71  dPow_mssd          180 non-null    float64
#  72  dHz_mssd           180 non-null    float64
#  73  pPow_mssd          180 non-null    float64
#  74  pHz_mssd           180 non-null    float64
#  75  CohRatio_mssd      180 non-null    float64
#  76  RSA_mssd           180 non-null    float64
#  77  dHz_diff_mssd      180 non-null    float64
#  78  BPM_autocorr       180 non-null    float64
#  79  SDNN_autocorr      180 non-null    float64
#  80  rMSSD_autocorr     180 non-null    float64
#  81  VLF_autocorr       180 non-null    float64
#  82  LF_autocorr        180 non-null    float64
#  83  HF_autocorr        180 non-null    float64
#  84  VLFp_autocorr      180 non-null    float64
#  85  LFp_autocorr       180 non-null    float64
#  86  HFp_autocorr       180 non-null    float64
#  87  lnVLF_autocorr     180 non-null    float64
#  88  lnLF_autocorr      180 non-null    float64
#  89  lnHF_autocorr      180 non-null    float64
#  90  VLF/HF_autocorr    180 non-null    float64
#  91  LF/HF_autocorr     180 non-null    float64
#  92  tPow_autocorr      180 non-null    float64
#  93  dPow_autocorr      180 non-null    float64
#  94  dHz_autocorr       180 non-null    float64
#  95  pPow_autocorr      180 non-null    float64
#  96  pHz_autocorr       180 non-null    float64
#  97  CohRatio_autocorr  180 non-null    float64
#  98  RSA_autocorr       180 non-null    float64
#  99  dHz_diff_autocorr  180 non-null    float64
# dtypes: float64(88), int64(11), object(1)
# memory usage: 140.8+ KB

# %%
df_arsl = pd.read_csv(ARSL_PATH)
df_arsl.head()
# Out:
#          name  year  score_EI  domain_EI  trainnig  group_EI  자극_Arousal  \
# 0  subj_01_00  2021       400          1         0         0           1
# 1  subj_01_01  2021       400          1         0         0           1
# 2  subj_01_02  2021       400          0         0         0           0
# 3  subj_01_03  2021       400          0         0         0           0
# 4  subj_02_00  2021       450          1         0         0           1
#
#    자극_Valence  Arousal  Valence  ...  VLF/HF_autocorr  LF/HF_autocorr  \
# 0           1        4        5  ...        -0.567119       -0.991761
# 1           0        6        4  ...        -2.854562       -1.532805
# 2           1        3        6  ...        -1.375726       -1.030548
# 3           0        4        4  ...        -0.198272        0.921968
# 4           1        6        7  ...         0.469754        0.216407
#
#    tPow_autocorr  dPow_autocorr  dHz_autocorr  pPow_autocorr  pHz_autocorr  \
# 0       4.761754      -0.106286     -0.597611      -0.177651     -1.020465
# 1      -4.013737      13.465573     -1.486156       0.136173     -0.504705
# 2       0.056760      -1.111399     -1.126756      -0.961825     -1.626310
# 3      -2.812514       7.058668     -0.880433      -0.866042     -0.602454
# 4       0.900575       0.121397      0.023057      -0.702703     -0.874824
#
#    CohRatio_autocorr  RSA_autocorr  dHz_diff_autocorr
# 0          -1.087973      1.085212          -0.595462
# 1          -0.481968      0.855739          -1.486156
# 2          -1.110674     -0.670813          -1.127433
# 3          -1.700471      0.168826          -0.880433
# 4           0.579896     -0.289846           0.023057
#
# [5 rows x 100 columns]

# %%
df_arsl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total
#  71  dPow_mssd          180 non-null    float64
#  72  dHz_mssd           180 non-null    float64
#  73  pPow_mssd          180 non-null    float64
#  74  pHz_mssd           180 non-null    float64
#  75  CohRatio_mssd      180 non-null    float64
#  76  RSA_mssd           180 non-null    float64
#  77  dHz_diff_mssd      180 non-null    float64
#  78  BPM_autocorr       180 non-null    float64
#  79  SDNN_autocorr      180 non-null    float64
#  80  rMSSD_autocorr     180 non-null    float64
#  81  VLF_autocorr       180 non-null    float64
#  82  LF_autocorr        180 non-null    float64
#  83  HF_autocorr        180 non-null    float64
#  84  VLFp_autocorr      180 non-null    float64
#  85  LFp_autocorr       180 non-null    float64
#  86  HFp_autocorr       180 non-null    float64
#  87  lnVLF_autocorr     180 non-null    float64
#  88  lnLF_autocorr      180 non-null    float64
#  89  lnHF_autocorr      180 non-null    float64
#  90  VLF/HF_autocorr    180 non-null    float64
#  91  LF/HF_autocorr     180 non-null    float64
#  92  tPow_autocorr      180 non-null    float64
#  93  dPow_autocorr      180 non-null    float64
#  94  dHz_autocorr       180 non-null    float64
#  95  pPow_autocorr      180 non-null    float64
#  96  pHz_autocorr       180 non-null    float64
#  97  CohRatio_autocorr  180 non-null    float64
#  98  RSA_autocorr       180 non-null    float64
#  99  dHz_diff_autocorr  180 non-null    float64
# dtypes: float64(88), int64(11), object(1)
# memory usage: 140.8+ KB

# %%
df_vlnc = pd.read_csv(VLNC_PATH)
df_vlnc.head()
# Out:
#          name  year  score_EI  domain_EI  trainnig  group_EI  자극_Arousal  \
# 0  subj_01_00  2021       400          1         0         0           1
# 1  subj_01_01  2021       400          0         0         0           1
# 2  subj_01_02  2021       400          1         0         0           0
# 3  subj_01_03  2021       400          0         0         0           0
# 4  subj_02_00  2021       450          1         0         0           1
#
#    자극_Valence  Arousal  Valence  ...  VLF/HF_autocorr  LF/HF_autocorr  \
# 0           1        4        5  ...        -0.567119       -0.991761
# 1           0        6        4  ...        -2.854562       -1.532805
# 2           1        3        6  ...        -1.375726       -1.030548
# 3           0        4        4  ...        -0.198272        0.921968
# 4           1        6        7  ...         0.469754        0.216407
#
#    tPow_autocorr  dPow_autocorr  dHz_autocorr  pPow_autocorr  pHz_autocorr  \
# 0       4.761754      -0.106286     -0.597611      -0.177651     -1.020465
# 1      -4.013737      13.465573     -1.486156       0.136173     -0.504705
# 2       0.056760      -1.111399     -1.126756      -0.961825     -1.626310
# 3      -2.812514       7.058668     -0.880433      -0.866042     -0.602454
# 4       0.900575       0.121397      0.023057      -0.702703     -0.874824
#
#    CohRatio_autocorr  RSA_autocorr  dHz_diff_autocorr
# 0          -1.087973      1.085212          -0.595462
# 1          -0.481968      0.855739          -1.486156
# 2          -1.110674     -0.670813          -1.127433
# 3          -1.700471      0.168826          -0.880433
# 4           0.579896     -0.289846           0.023057
#
# [5 rows x 100 columns]

# %%
df_vlnc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 100 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name
#  84  VLFp_autocorr      180 non-null    float64
#  85  LFp_autocorr       180 non-null    float64
#  86  HFp_autocorr       180 non-null    float64
#  87  lnVLF_autocorr     180 non-null    float64
#  88  lnLF_autocorr      180 non-null    float64
#  89  lnHF_autocorr      180 non-null    float64
#  90  VLF/HF_autocorr    180 non-null    float64
#  91  LF/HF_autocorr     180 non-null    float64
#  92  tPow_autocorr      180 non-null    float64
#  93  dPow_autocorr      180 non-null    float64
#  94  dHz_autocorr       180 non-null    float64
#  95  pPow_autocorr      180 non-null    float64
#  96  pHz_autocorr       180 non-null    float64
#  97  CohRatio_autocorr  180 non-null    float64
#  98  RSA_autocorr       180 non-null    float64
#  99  dHz_diff_autocorr  180 non-null    float64
# dtypes: float64(88), int64(11), object(1)
# memory usage: 140.8+ KB

# %% [markdown]
# ## Step 1: Experiment Settings
# Define Scaling and Setup for PyCaret
#
# We define three types of scaling: none, standard, and min-max, for every feature configuration.

# %%
TARGET = "domain_EI"

# Columns that are never used as features
MUST_EXCLUDE = [
    "name", "domain_EI", "year", "trainnig",
    "Arousal", "Valence", "자극_Arousal", "자극_Valence",
    "Subj_AR", "Subj_PN"
]

# 4 feature-set flavours: keep / drop EI score / drop EI group / drop both
FEATURE_EXCLUDE_SETS = {
    1: [],
    2: ["group_EI"],
    3: ["score_EI"],
    4: ["score_EI", "group_EI"],
}

# Three scaler options
SCALERS = {
    "none":     None,
    "standard": StandardScaler(),
    "minmax":   MinMaxScaler(),
}

# Models we allow PyCaret to try
INCLUDE_MODELS = [
    "catboost", "xgboost", "rf", "et",
    "lr", "nb", "svm", "knn", "qda",
]

# %% [markdown]
# ####  LightGBM stub

# %%
lgb_stub = types.ModuleType("lightgbm")

class _DummyLGBM:
    """Minimal fake LightGBM estimator so that PyCaret can import it."""
    def __init__(self, *args, **kwargs): pass
    def fit(self, *args, **kwargs): return self
    def predict(self, X, *args, **kwargs):          # label output
        return np.zeros(len(X), dtype=int)
    def predict_proba(self, X, *args, **kwargs):    # proba output
        # return 2-col dummy probs for binary; PyCaret only checks shape
        return np.zeros((len(X), 2), dtype=float)

# expose expected symbols at top level
lgb_stub.LGBMClassifier = _DummyLGBM
lgb_stub.LGBMRegressor  = _DummyLGBM
lgb_stub.Dataset        = object          # rarely used by PyCaret

basic_stub = types.ModuleType("lightgbm.basic")
basic_stub.LightGBMError = RuntimeError    # any Exception subclass works

# make `from lightgbm.basic import LightGBMError` succeed
sys.modules["lightgbm.basic"] = basic_stub

# attach sub-module to the parent package stub
lgb_stub.basic = basic_stub

sys.modules["lightgbm"] = lgb_stub

# %% [markdown]
# ## Step 2. Result Containers

# %%
results_multi:     list[dict]        = []     # one row per config+scaler
best_models_multi: dict[str, object] = {}     # tag ➜ fitted model

results_arsl:     list[dict]        = []     # one row per config+scaler
best_models_arsl: dict[str, object] = {}     # tag ➜ fitted model

results_vlnc:     list[dict]        = []     # one row per config+scaler
best_models_vlnc: dict[str, object] = {}     # tag ➜ fitted model

# %% [markdown]
# ## Step 3: AutoML Training using PyCaret + tqdm Progress Tracking
# WITHOUT OUTLIER vs WITH OUTLIER !! (With Outlier first)
#
# We train models using PyCaret with GPU acceleration, over 8 × 3 configuration combinations.
# '''
# for config_id, exclude_cols in tqdm(feature_exclude_sets.items(), desc="Feature Configs", position=0):
#     for scaler_name, scaler in tqdm(scalers.items(), desc=f"Scalers for Config {config_id}", leave=False, position=1):
#         df_exp = df.copy()
#         all_excluded = must_exclude + exclude_cols
#
#         remaining_cols = [col for col in df_exp.columns if col not in all_excluded]
#         if len(remaining_cols) == 0:
#             print(f"⚠️ Skipping config {config_id} + scaler {scaler_name} – no features left.")
#             continue
#
#         X = df_exp.drop(columns=all_excluded)
#         y = df_exp[target]
#
#         X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=42)
#
#         # ✅ Feature Check
#         print(f"\n📌 Config {config_id} | Scaler: {scaler_name}")
#         print(f"🔸 X_train shape: {X_train.shape}")
#         print(f"🔸 Feature columns: {list(X_train.columns)}")
#         print(f"🔸 Null values:\n{X_train.isnull().sum()}")
#         print(f"🔸 Class distribution:\n{y_train.value_counts()}")
#         print("-" * 60)
# '''

# %% [markdown]
# ### Step 2.3. Experiment loop

# %% [markdown]
# ### Multi

# %%
for cfg_id, excl_cols in tqdm(FEATURE_EXCLUDE_SETS.items(),
                              desc="Feature Configs"):

    for scaler_name, scaler in tqdm(SCALERS.items(),
                                    desc=f"Scalers for {cfg_id}",
                                    leave=False):

        # 3-1 ▶ split -------------------------------------------------------
        X = df_multi.drop(columns=MUST_EXCLUDE + excl_cols)
        y = df_multi[TARGET]
        X_tr, X_te, y_tr, y_te = train_test_split(
            X, y, stratify=y, test_size=0.10, random_state=42
        )

        if X_tr.shape[1] == 0:             # empty feature guard
            print(f"🚫 cfg{cfg_id}|{scaler_name}: no features"); continue

        # 3-2 ▶ optional scaling -------------------------------------------
        if scaler:
            X_tr = pd.DataFrame(scaler.fit_transform(X_tr),
                                index=X_tr.index, columns=X_tr.columns)
            X_te = pd.DataFrame(scaler.transform(X_te),
                                index=X_te.index, columns=X_te.columns)

        # 3-3 ▶ PyCaret setup  --------------------------------------------
        train_df = pd.concat([X_tr.reset_index(drop=True),
                              y_tr.reset_index(drop=True)], axis=1)
        test_df  = pd.concat([X_te.reset_index(drop=True),
                              y_te.reset_index(drop=True)], axis=1)

        setup(
            data=train_df,
            test_data=test_df,     # 👈 pass *your* hold-out here
            target=TARGET,
            session_id=42,
            fold=3,
            use_gpu=False,
            html=True,
            verbose=True,
            feature_selection=False,
            index=False,
        )

        # 3-4 ▶ model search  ---------------------------------------------
        best = compare_models(include=INCLUDE_MODELS,
                              sort="AUC",   fold=3,
                              turbo=False, verbose=True)

        tag = f"cfg{cfg_id}_{scaler_name}"
        best_models_multi[tag] = best

        # leaderboard CSV ---------------------------------------------------
        pull().assign(config=cfg_id, scaler=scaler_name) \
              .to_csv(os.path.join(RES_MULTI_PATH, f"leaderboard_{tag}.csv"),
                      index=False)

        # 3-5 ▶ predict on hold-out & plots -------------------------------
        pred = predict_model(best)     # uses test_data provided in setup()

        plot_model(best, plot="confusion_matrix",   save=True)
        os.replace("Confusion Matrix.png",
                   os.path.join(CM_MULTI_PATH,  f"CM_{tag}.png"))

        # AUC — only if model supports probability estimates
        if hasattr(best, "predict_proba"):
            plot_model(best, plot="auc", save=True)
            if os.path.exists("AUC.png"):
                os.replace("AUC.png", os.path.join(AUC_MULTI_PATH, f"AUC_{tag}.png"))
        else:
            print(f"[SKIP] AUC not available for {tag}")

        # 3-6 ▶ feature importance ----------------------------------------
        fi_path = os.path.join(FI_MULTI_PATH, f"FI_{tag}.png")

        def save_fi_tree():
            plot_model(best, plot="feature", save=True)
            os.replace("Feature Importance.png", fi_path)

        if hasattr(best, "feature_importances_"):
            save_fi_tree()

        elif best.__class__.__name__.startswith("CatBoost"):
            fi = best.get_feature_importance()
            top = np.argsort(fi)[::-1][:20]
            plt.figure(figsize=(6, 4))
            plt.barh(range(len(top)), fi[top][::-1])
            plt.yticks(range(len(top)), X_tr.columns[top][::-1])
            plt.tight_layout(); plt.savefig(fi_path); plt.close()

        # 3-7 ▶ collect numeric summary -----------------------------------
        cv_metrics = pull().iloc[0]        # row 0 = best model’s CV stats
        results_multi.append({
            "config":      cfg_id,
            "scaler":      scaler_name,
            "model":       best.__class__.__name__,
            "AUC_CV":      cv_metrics["AUC"],
            "Acc_CV":      cv_metrics["Accuracy"],
            "Acc_holdout": (pred[TARGET] == pred["prediction_label"]).mean(),
        })
# Out:
# Feature Configs:   0%|          | 0/4 [00:00<?, ?it/s]
# <style type="text/css">
# #T_5cd6e_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5cd6e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5cd6e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_5cd6e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5cd6e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5cd6e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_5cd6e_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_5cd6e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5cd6e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_5cd6e_row1_col1" class="data row1 col1" >domain_EI</td>
#     </tr>
#     <tr>
#       <th id="T_5cd6e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5cd6e_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_5cd6e_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_5cd6e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5cd6e_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_5cd6e_row3_col1" class="data row3 col1" >(180, 91)</td>
#     </tr>
#     <tr>
#       <th id="T_5cd6e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5cd6e_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_5cd6e_row4_col1" class="data row4 col1" >(180, 91)</td>
#     </tr>
#     <tr>
#       <th id="T_5cd6e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5cd6e_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_5cd6e_row5_col1" class="data row5 col1" >(162, 91)</td>
#     </tr>
#     <tr>
#       <th id="T_5cd6e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5cd6e_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_5cd6e_row6_col1" class="data row6 col1" >(18, 91)</td>
#     </tr>
#     <tr>
#       <th id="T_5cd6e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5cd6e_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_5cd6e_row7_col1" class="data row7 col1" >90</td>
#     </tr>
#     <tr>
#       <th id="T_5cd6e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5cd6e_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_5cd6e_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5cd6e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5cd6e_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_5cd6e_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_5cd6e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_5cd6e_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_5cd6e_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_5cd6e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_5cd6e_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_5cd6e_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_5cd6e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_5cd6e_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_5cd6e_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_5cd6e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_5cd6e_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_5cd6e_row13_col1" class="data row13 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_5cd6e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_5cd6e_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_5cd6e_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_5cd6e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_5cd6e_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_5cd6e_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5cd6e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_5cd6e_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_5cd6e_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5cd6e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_5cd6e_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_5cd6e_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_5cd6e_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_5cd6e_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_5cd6e_row18_col1" class="data row18 col1" >9c75</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_9e71a th {
#   text-align: left;
# }
# #T_9e71a_row0_col0, #T_9e71a_row0_col1, #T_9e71a_row0_col3, #T_9e71a_row0_col4, #T_9e71a_row0_col5, #T_9e71a_row0_col6, #T_9e71a_row0_col7, #T_9e71a_row1_col0, #T_9e71a_row1_col2, #T_9e71a_row1_col4, #T_9e71a_row2_col0, #T_9e71a_row2_col1, #T_9e71a_row2_col2, #T_9e71a_row2_col3, #T_9e71a_row2_col4, #T_9e71a_row2_col5, #T_9e71a_row2_col6, #T_9e71a_row2_col7, #T_9e71a_row3_col0, #T_9e71a_row3_col1, #T_9e71a_row3_col2, #T_9e71a_row3_col3, #T_9e71a_row3_col4, #T_9e71a_row3_col5, #T_9e71a_row3_col6, #T_9e71a_row3_col7, #T_9e71a_row4_col0, #T_9e71a_row4_col1, #T_9e71a_row4_col2, #T_9e71a_row4_col3, #T_9e71a_row4_col4, #T_9e71a_row4_col5, #T_9e71a_row4_col6, #T_9e71a_row4_col7, #T_9e71a_row5_col0, #T_9e71a_row5_col1, #T_9e71a_row5_col2, #T_9e71a
level0_row4" class="row_heading level0 row4" >catboost</th>
#       <td id="T_46c8b_row4_col0" class="data row4 col0" >CatBoost Classifier</td>
#       <td id="T_46c8b_row4_col1" class="data row4 col1" >0.2099</td>
#       <td id="T_46c8b_row4_col2" class="data row4 col2" >0.4283</td>
#       <td id="T_46c8b_row4_col3" class="data row4 col3" >0.2099</td>
#       <td id="T_46c8b_row4_col4" class="data row4 col4" >0.2072</td>
#       <td id="T_46c8b_row4_col5" class="data row4 col5" >0.2026</td>
#       <td id="T_46c8b_row4_col6" class="data row4 col6" >-0.0527</td>
#       <td id="T_46c8b_row4_col7" class="data row4 col7" >-0.0535</td>
#       <td id="T_46c8b_row4_col8" class="data row4 col8" >2.6700</td>
#     </tr>
#     <tr>
#       <th id="T_46c8b_level0_row5" class="row_heading level0 row5" >rf</th>
#       <td id="T_46c8b_row5_col0" class="data row5 col0" >Random Forest Classifier</td>
#       <td id="T_46c8b_row5_col1" class="data row5 col1" >0.1914</td>
#       <td id="T_46c8b_row5_col2" class="data row5 col2" >0.4263</td>
#       <td id="T_46c8b_row5_col3" class="data row5 col3" >0.1914</td>
#       <td id="T_46c8b_row5_col4" class="data row5 col4" >0.1943</td>
#       <td id="T_46c8b_row5_col5" class="data row5 col5" >0.1900</td>
#       <td id="T_46c8b_row5_col6" class="data row5 col6" >-0.0772</td>
#       <td id="T_46c8b_row5_col7" class="data row5 col7" >-0.0777</td>
#       <td id="T_46c8b_row5_col8" class="data row5 col8" >0.0467</td>
#     </tr>
#     <tr>
#       <th id="T_46c8b_level0_row6" class="row_heading level0 row6" >lr</th>
#       <td id="T_46c8b_row6_col0" class="data row6 col0" >Logistic Regression</td>
#       <td id="T_46c8b_row6_col1" class="data row6 col1" >0.2654</td>
#       <td id="T_46c8b_row6_col2" class="data row6 col2" >0.0000</td>
#       <td id="T_46c8b_row6_col3" class="data row6 col3" >0.2654</td>
#       <td id="T_46c8b_row6_col4" class="data row6 col4" >0.2601</td>
#       <td id="T_46c8b_row6_col5" class="data row6 col5" >0.2526</td>
#       <td id="T_46c8b_row6_col6" class="data row6 col6" >0.0219</td>
#       <td id="T_46c8b_row6_col7" class="data row6 col7" >0.0223</td>
#       <td id="T_46c8b_row6_col8" class="data row6 col8" >0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_46c8b_level0_row7" class="row_heading level0 row7" >svm</th>
#       <td id="T_46c8b_row7_col0" class="data row7 col0" >
# <style type="text/css">
# </style>
# <table id="T_14ece">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_14ece_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_14ece_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_14ece_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_14ece_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_14ece_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_14ece_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_14ece_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_14ece_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_14ece_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_14ece_row0_col0" class="data row0 col0" >Extreme Gradient Boosting</td>
#       <td id="T_14ece_row0_col1" class="data row0 col1" >0.2778</td>
#       <td id="T_14ece_row0_col2" class="data row0 col2" >0.5446</td>
#       <td id="T_14ece_row0_col3" class="data row0 col3" >0.2778</td>
#       <td id="T_14ece_row0_col4" class="data row0 col4" >0.3481</td>
#       <td id="T_14ece_row0_col5" class="data row0 col5" >0.2846</td>
#       <td id="T_14ece_row0_col6" class="data row0 col6" >0.0526</td>
#       <td id="T_14ece_row0_col7" class="data row0 col7" >0.0561</td>
#     </tr>
#   </tbody>
# </table>
# Feature Configs:  25%|██▌       | 1/4 [00:39<01:57, 39.26s/it]
# <style type="text/css">
# #T_0c42b_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_0c42b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0c42b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_0c42b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0c42b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0c42b_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_0c42b_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_0c42b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0c42b_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_0c42b_row1_col1" class="data row1 col1" >domain_EI</td>
#     </tr>
#     <tr>
#       <th id="T_0c42b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0c42b_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_0c42b_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_0c42b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0c42b_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_0c42b_row3_col1" class="data row3 col1" >(180, 90)</td>
#     </tr>
#     <tr>
#       <th id="T_0c42b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0c42b_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_0c42b_row4_col1" class="data row4 col1" >(180, 90)</td>
#     </tr>
#     <tr>
#       <th id="T_0c42b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0c42b_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_0c42b_row5_col1" class="data row5 col1" >(162, 90)</td>
#     </tr>
#     <tr>
#       <th id="T_0c42b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0c42b_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_0c42b_row6_col1" class="data row6 col1" >(18, 90)</td>
#     </tr>
#     <tr>
#       <th id="T_0c42b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0c42b_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_0c42b_row7_col1" class="data row7 col1" >89</td>
#     </tr>
#     <tr>
#       <th id="T_0c42b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0c42b_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_0c42b_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_0c42b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0c42b_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_0c42b_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_0c42b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_0c42b_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_0c42b_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_0c42b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_0c42b_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_0c42b_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_0c42b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_0c42b_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_0c42b_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_0c42b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_0c42b_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_0c42b_row13_col1" class="data row13 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_0c42b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_0c42b_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_0c42b_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_0c42b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_0c42b_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_0c42b_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_0c42b_level0_row16" class="row_heading level0 row16" >16</th>
# ...
# </style>
# <table id="T_45d60">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_45d60_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_45d60_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_45d60_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_45d60_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_45d60_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_45d60_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_45d60_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_45d60_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_45d60_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_45d60_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_45d60_row0_col1" class="data row0 col1" >0.1667</td>
#       <td id="T_45d60_row0_col2" class="data row0 col2" >0.4492</td>
#       <td id="T_45d60_row0_col3" class="data row0 col3" >0.1667</td>
#       <td id="T_45d60_row0_col4" class="data row0 col4" >0.1481</td>
#       <td id="T_45d60_row0_col5" class="data row0 col5" >0.1556</td>
#       <td id="T_45d60_row0_col6" class="data row0 col6" >-0.1066</td>
#       <td id="T_45d60_row0_col7" class="data row0 col7" >-0.1083</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_d4ea4_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d4ea4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d4ea4_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d4ea4_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d4ea4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d4ea4_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d4ea4_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_d4ea4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d4ea4_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d4ea4_row1_col1" class="data row1 col1" >domain_EI</td>
#     </tr>
#     <tr>
#       <th id="T_d4ea4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d4ea4_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_d4ea4_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_d4ea4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d4ea4_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_d4ea4_row3_col1" class="data row3 col1" >(180, 89)</td>
#     </tr>
#     <tr>
#       <th id="T_d4ea4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d4ea4_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_d4ea4_row4_col1" class="data row4 col1" >(180, 89)</td>
#     </tr>
#     <tr>
#       <th id="T_d4ea4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d4ea4_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_d4ea4_row5_col1" class="data row5 col1" >(162, 89)</td>
#     </tr>
#     <tr>
#       <th id="T_d4ea4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d4ea4_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_d4ea4_row6_col1" class="data row6 col1" >(18, 89)</td>
#     </tr>
#     <tr>
#       <th id="T_d4ea4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d4ea4_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_d4ea4_row7_col1" class="data row7 col1" >88</td>
#     </tr>
#     <tr>
#       <th id="T_d4ea4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d4ea4_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_d4ea4_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d4ea4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d4ea4_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_d4ea4_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_d4ea4_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d4ea4_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_d4ea4_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_d4ea4_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d4ea4_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_d4ea4_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_d4ea4_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d4ea4_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_d4ea4_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_d4ea4_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d4ea4_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_d4ea4_row13_col1" class="data row13 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_d4ea4_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d4ea4_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_d4ea4_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_d4ea4_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d4ea4_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_d4ea4_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d4ea4_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_d4ea4_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_d4ea4_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d4ea4_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_d4ea4_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_d4ea4_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_d4ea4_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_d4ea4_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_d4ea4_row18_col1" class="data row18 col1" >ef08</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_bc27e th {
#   text-align: left;
# }
# #T_bc27e_row0_col0, #T_bc27e_row0_col1, #T_bc27e_row0_col3, #T_bc27e_row0_col4, #T_bc27e_row0_col5, #T_bc27e_row0_col6, #T_bc27e_row0_col7, #T_bc27e_row1_col0, #T_bc27e_row1_col1, #T_bc27e_row1_col2, #T_bc27e_row1_col3, #T_bc27e_row1_col5, #T_bc27e_row1_col6, #T_bc27e_row1_col7, #T_bc27e_row2_col0, #T_bc27e_row2_col2, #T_bc27e_row2_col4, #T_bc27e_row2_col6, #T_bc27e_row2_col7, #T_bc27e_row3_col0, #T_bc27e_row3_col1, #T_bc27e_row3_col2, #T_bc27e_row3_col3, #T_bc27e_row3_col4, #T_bc27e_row3_col5, #T_bc27e_row3_col6, #T_bc27e_row3_col7, #T_bc27e_row4_col0, #T_bc27e_row4_col1, #T_bc27e_row4_col2, #T_bc27e_row4_col3, #T_bc27e_row4_col4, #T_bc27e_row4_col5, #T_bc27e_row4_col6, #T_bc27e_row4_col7, #T_bc27e_row5_col0, #T_bc27e_row5_col1, #T_bc27e_row5_col2, #T_bc27e_row5_col3, #T_bc27e_row5_col4, #T_bc27e_row5_col5, #T_bc27e_row5_col6, #T_bc27e_row5_col7, #T_bc27e_row6_col0, #T_bc27e_row6_col2, #T_bc27e_row6_col4, #T_bc27e_row6_col5, #T_bc27e_row6_col6, #T_bc27e_row6_col7, #T_bc27e_row7_col0, #T_bc27e_row7_col2, #T_bc27e_row7_col4, #T_bc27e_row7_col5, #T_bc27e_row8_col0, #T_bc27e_row8_col1, #T_bc27e_row8_col2, #T_bc27e_row8_col3, #T_bc27e_row8_col4, #T_bc27e_row8_col5, #T_bc27e_row8_col6, #T_bc27e_row8_col7 {
#   text-align: left;
# }
# #T_bc27e_row0_col2, #T_bc27e_row1_col4, #T_bc27e_row2_col1, #T_bc27e_row2_col3, #T_bc27e_row2_col5, #T_bc27e_row6_col1, #T_bc27e_row6_col3, #T_bc27e_row7_col1, #T_bc27e_row7_col3, #T_bc27e_row7_col6, #T_bc27e_row7_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_bc27e_row0_col8, #T_bc27e_row2_col8, #T_bc27e_row3_col8, #T_bc27e_row4_col8, #T_bc27e_row5_col8, #T_bc27e_row6_col8, #T_bc27e_row7_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_bc27e_row1_col8, #T_bc27e_row8_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_bc27e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bc27e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_bc27e_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_bc27e_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_bc27e_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_bc27e_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_bc27e_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_bc27e_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_bc27e_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_bc27e_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bc27e_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_bc27e_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_bc27e_row0_col1" class="data row0 col1" >0.2593</td>
#       <td id="T_bc27e_row0_col2" class="data row0 col2" >0.4934</td>
#       <td id="T_bc27e_row0_col3" class="data row0 col3" >0.2593</td>
#       <td id="T_bc27e_row0_col4" class="data row0 col4" >0.2591</td>
#       <td id="T_bc27e_row0_col5" class="data row0 col5" >0.2492</td>
#       <td id="T_bc27e_row0_col6" class="data row0 col6" >0.0125</td>
#       <td id="T_bc27e_row0_col7" class="data row0 col7" >0.0129</td>
#       <td id="T_bc27e_row0_col8" class="data row0 col8" >0.0367</td>
#     </tr>
#     <tr>
#       <th id="T_bc27e_level0_row1" class="row_heading level0 row1" >nb</th>
#       <td id="T_bc27e_row1_col0" class="data row1 col0" >Naive Bayes</td>
#       <td id="T_bc27e_row1_col1" class="data row1 col1" >0.2531</td>
#       <td id="T_bc27e_row1_col2" class="data row1 col2" >0.4784</td>
#       <td id="T_bc27e_row1_col3" class="data row1 col3" >0.2531</td>
#       <td id="T_bc27e_row1_col4" class="data row1 col4" >0.2639</td>
#       <td id="T_bc27e_row1_col5" class="data row1 col5" >0.2441</td>
#       <td id="T_bc27e_row1_col6" class="data row1 col6" >0.0020</td>
#       <td id="T_bc27e_row1_col7" class="data row1 col7" >0.0034</td>
#       <td id="T_bc27e_row1_col8" class="data row1 col8" >0.0067</td>
#     </tr>
#     <tr>
#       <th id="T_bc27e_level0_row2" class="row_heading level0 row2" >xgboost</th>
#       <td id="T_bc27e_row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#       <td id="T_bc27e_row2_col1" class="data row2 col1" >0.2654</td>
#       <td id="T_bc27e_row2_col2" class="data row2 col2" >0.4747</td>
#       <td id="T_bc27e_row2_col3" class="data row2 col3" >0.2654</td>
#       <td id="T_bc27e_row2_col4" class="data row2 col4" >0.2543</td>
#       <td id="T_bc27e_row2_col5" class="data row2 col5" >0.2578</td>
#       <td id="T_bc27e_row2_col6" class="data row2 col6" >0.0216</td>
#       <td id="T_bc27e_row2_col7" class="data row2 col7" >0.0218</td>
#       <td id="T_bc27e_row2_col8" class="data row2 col8" >0.1500</td>
#     </tr>
#     <tr>
#       <th id="T_bc27e_level0_row3" class="row_heading level0 row3" >catboost</th>
#       <td id="T_bc27e_row3_col0" class="data row3 col0" >CatBoost Classifier</td>
#       <td id="T_bc27e_row3_col1" class="data row3 col1" >0.2284</td>
#       <td id="T_bc27e_row3_col2" class="data row3 col2" >0.4657</td>
#       <td id="T_bc27e_row3_col3" class="data row3 col3" >0.2284</td>
#       <td id="T_bc27e_row3_col4" class="data row3 col4" >0.2198</td>
#       <td id="T_bc27e_row3_col5" class="data row3 col5" >0.2169</td>
#       <td id="T_bc27e_row3_col6" class="data row3 col6" >-0.0270</td>
#       <td id="T_bc27e_row3_col7" class="data row3 col7" >-0.0280</td>
#       <td id="T_bc27e_row3_col8" class="data row3 col8" >2.6033</td>
#     </tr>
#     <tr>
#       <th id="T_bc27e_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_bc27e_row4_col0" class="data row4 col0" >Random Forest Classifier</td>
#       <td id="T_bc27e_row4_col1" class="data row4 col1" >0.2469</td>
#       <td id="T_bc27e_row4_col2" class="data row4 col2" >0.4523</td>
#       <td id="T_bc27e_row4_col3" class="data row4 col3" >0.2469</td>
#       <td id="T_bc27e_row4_col4" class="data row4 col4" >0.2349</td>
#       <td id="T_bc27e_row4_col5" class="data row4 col5" >0.2342</td>
#       <td id="T_bc27e_row4_col6" class="data row4 col6" >-0.0034</td>
#       <td id="T_bc27e_row4_col7" class="data row4 col7" >-0.0030</td>
#       <td id="T_bc27e_row4_col8" class="data row4 col8" >0.0467</td>
#     </tr>
#     <tr>
#       <th id="T_bc27e_level0_row5" class="row_heading level0 row5" >knn</th>
#       <td id="T_bc27e_row5_col0" class="data row5 col0" >K Neighbors Classifier</td>
#       <td id="T_bc27e_row5_col1" class="data row5 col1" >0.2222</td>
#       <td id="T_bc27e_row5_col2" class="data row5 col2" >0.4484</td>
#       <td id="T_bc27e_row5_col3" class="data row5 col3" >0.2222</td>
#       <td id="T_bc27e_row5_col4" class="data row5 col4" >0.2115</td>
#       <td id="T_bc27e_row5_col5" class="data row5 col5" >0.2094</td>
#       <td id="T_bc27e_row5_col6" class="data row5 col6" >-0.0384</td>
#       <td id="T_bc27e_row5_col7" class="data row5 col7" >-0.0397</td>
#       <td id="T_bc27e_row5_col8" class="data row5 col8" >0.0133</td>
#     </tr>
#     <tr>
#       <th id="T_bc27e_level0_row6" class="row_heading level0 row6" >lr</th>
#       <td id="T_bc27e_row6_col0" class="data row6 col0" >Logistic Regression</td>
#       <td id="T_bc27e_row6_col1" class="data row6 col1" >0.2654</td>
#       <td id="T_bc27e_row6_col2" class="data row6 col2" >0.0000</td>
#       <td id="T_bc27e_row6_col3" class="data row6 col3" >0.2654</td>
#       <td id="T_bc27e_row6_col4" class="data row6 col4" >0.2534</td>
#       <td id="T_bc27e_row6_col5" class="data row6 col5" >0.2539</td>
#       <td id="T_bc27e_row6_col6" class="data row6 col6" >0.0217</td>
#       <td id="T_bc27e_row6_col7" class="data row6 col7" >0.0220</td>
#       <td id="T_bc27e_row6_col8" class="data row6 col8" >0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_bc27e_level0_row7" class="row_heading level0 row7" >svm</th>
#       <td id="T_bc27e_row7_col0" class="data row7 col0" >SV
# <style type="text/css">
# </style>
# <table id="T_9614c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9614c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_9614c_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_9614c_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_9614c_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_9614c_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_9614c_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_9614c_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_9614c_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9614c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9614c_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_9614c_row0_col1" class="data row0 col1" >0.2222</td>
#       <td id="T_9614c_row0_col2" class="data row0 col2" >0.4361</td>
#       <td id="T_9614c_row0_col3" class="data row0 col3" >0.2222</td>
#       <td id="T_9614c_row0_col4" class="data row0 col4" >0.1889</td>
#       <td id="T_9614c_row0_col5" class="data row0 col5" >0.2037</td>
#       <td id="T_9614c_row0_col6" class="data row0 col6" >-0.0328</td>
#       <td id="T_9614c_row0_col7" class="data row0 col7" >-0.0332</td>
#     </tr>
#   </tbody>
# </table>
# Feature Configs: 100%|██████████| 4/4 [02:17<00:00, 34.43s/it]

# %% [markdown]
# ### Arsl

# %%
for cfg_id, excl_cols in tqdm(FEATURE_EXCLUDE_SETS.items(),
                              desc="Feature Configs"):

    for scaler_name, scaler in tqdm(SCALERS.items(),
                                    desc=f"Scalers for {cfg_id}",
                                    leave=False):

        # 3-1 ▶ split -------------------------------------------------------
        X = df_arsl.drop(columns=MUST_EXCLUDE + excl_cols)
        y = df_arsl[TARGET]
        X_tr, X_te, y_tr, y_te = train_test_split(
            X, y, stratify=y, test_size=0.10, random_state=42
        )

        if X_tr.shape[1] == 0:             # empty feature guard
            print(f"🚫 cfg{cfg_id}|{scaler_name}: no features"); continue

        # 3-2 ▶ optional scaling -------------------------------------------
        if scaler:
            X_tr = pd.DataFrame(scaler.fit_transform(X_tr),
                                index=X_tr.index, columns=X_tr.columns)
            X_te = pd.DataFrame(scaler.transform(X_te),
                                index=X_te.index, columns=X_te.columns)

        # 3-3 ▶ PyCaret setup  --------------------------------------------
        train_df = pd.concat([X_tr.reset_index(drop=True),
                              y_tr.reset_index(drop=True)], axis=1)
        test_df  = pd.concat([X_te.reset_index(drop=True),
                              y_te.reset_index(drop=True)], axis=1)

        setup(
            data=train_df,
            test_data=test_df,     # 👈 pass *your* hold-out here
            target=TARGET,
            session_id=42,
            fold=3,
            use_gpu=False,
            html=True,
            verbose=True,
            feature_selection=False,
            index=False,
        )

        # 3-4 ▶ model search  ---------------------------------------------
        best = compare_models(include=INCLUDE_MODELS,
                              sort="AUC",   fold=3,
                              turbo=False, verbose=True)

        tag = f"cfg{cfg_id}_{scaler_name}"
        best_models_arsl[tag] = best

        # leaderboard CSV ---------------------------------------------------
        pull().assign(config=cfg_id, scaler=scaler_name) \
              .to_csv(os.path.join(RES_ARSL_PATH, f"leaderboard_{tag}.csv"),
                      index=False)

        # 3-5 ▶ predict on hold-out & plots -------------------------------
        pred = predict_model(best)     # uses test_data provided in setup()

        plot_model(best, plot="confusion_matrix",   save=True)
        os.replace("Confusion Matrix.png",
                   os.path.join(CM_ARSL_PATH,  f"CM_{tag}.png"))
        
        # AUC — only if model supports probability estimates
        if hasattr(best, "predict_proba"):
            plot_model(best, plot="auc", save=True)
            if os.path.exists("AUC.png"):
                os.replace("AUC.png", os.path.join(AUC_ARSL_PATH, f"AUC_{tag}.png"))
        else:
            print(f"[SKIP] AUC not available for {tag}")

        # 3-6 ▶ feature importance ----------------------------------------
        fi_path = os.path.join(FI_ARSL_PATH, f"FI_{tag}.png")

        def save_fi_tree():
            plot_model(best, plot="feature", save=True)
            os.replace("Feature Importance.png", fi_path)

        if hasattr(best, "feature_importances_"):
            save_fi_tree()

        elif best.__class__.__name__.startswith("CatBoost"):
            fi = best.get_feature_importance()
            top = np.argsort(fi)[::-1][:20]
            plt.figure(figsize=(6, 4))
            plt.barh(range(len(top)), fi[top][::-1])
            plt.yticks(range(len(top)), X_tr.columns[top][::-1])
            plt.tight_layout(); plt.savefig(fi_path); plt.close()

        # 3-7 ▶ collect numeric summary -----------------------------------
        cv_metrics = pull().iloc[0]        # row 0 = best model’s CV stats
        results_arsl.append({
            "config":      cfg_id,
            "scaler":      scaler_name,
            "model":       best.__class__.__name__,
            "AUC_CV":      cv_metrics["AUC"],
            "Acc_CV":      cv_metrics["Accuracy"],
            "Acc_holdout": (pred[TARGET] == pred["prediction_label"]).mean(),
        })
# Out:
# Feature Configs:   0%|          | 0/4 [00:00<?, ?it/s]
# <style type="text/css">
# #T_359cd_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_359cd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_359cd_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_359cd_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_359cd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_359cd_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_359cd_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_359cd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_359cd_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_359cd_row1_col1" class="data row1 col1" >domain_EI</td>
#     </tr>
#     <tr>
#       <th id="T_359cd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_359cd_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_359cd_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_359cd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_359cd_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_359cd_row3_col1" class="data row3 col1" >(180, 91)</td>
#     </tr>
#     <tr>
#       <th id="T_359cd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_359cd_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_359cd_row4_col1" class="data row4 col1" >(180, 91)</td>
#     </tr>
#     <tr>
#       <th id="T_359cd_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_359cd_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_359cd_row5_col1" class="data row5 col1" >(162, 91)</td>
#     </tr>
#     <tr>
#       <th id="T_359cd_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_359cd_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_359cd_row6_col1" class="data row6 col1" >(18, 91)</td>
#     </tr>
#     <tr>
#       <th id="T_359cd_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_359cd_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_359cd_row7_col1" class="data row7 col1" >90</td>
#     </tr>
#     <tr>
#       <th id="T_359cd_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_359cd_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_359cd_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_359cd_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_359cd_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_359cd_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_359cd_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_359cd_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_359cd_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_359cd_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_359cd_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_359cd_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_359cd_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_359cd_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_359cd_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_359cd_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_359cd_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_359cd_row13_col1" class="data row13 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_359cd_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_359cd_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_359cd_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_359cd_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_359cd_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_359cd_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_359cd_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_359cd_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_359cd_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_359cd_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_359cd_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_359cd_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_359cd_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_359cd_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_359cd_row18_col1" class="data row18 col1" >916e</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_46177 th {
#   text-align: left;
# }
# #T_46177_row0_col0, #T_46177_row0_col1, #T_46177_row0_col4, #T_46177_row0_col6, #T_46177_row0_col7, #T_46177_row1_col0, #T_46177_row1_col2, #T_46177_row1_col3, #T_46177_row1_col5, #T_46177_row2_col0, #T_46177_row2_col1, #T_46177_row2_col2, #T_46177_row2_col3, #T_46177_row2_col4, #T_46177_row2_col5, #T_46177_row2_col6, #T_46177_row2_col7, #T_46177_row3_col0, #T_46177_row3_col1, #T_46177_row3_col2, #T_46177_row3_col3, #T_46177_row3_col4, #T_46177_row3_col5, #T_46177_row3_col6, #T_46177_row3_col7, #T_46177_row4_col0, #T_46177_row4_col1, #T_46177_row4_col2, #T_46177_row4_col3, #T_46177_row4_col4, #T_46177_row4_col5, #T_46177_row4_col6, #T_46177_row4_col7, #T_46177_row5_col0, #T_46177_row5_col1, #T_46177_row5_col2, #T_46177_row5_col3, #T_46177_row5_col4, #T_46177_row5_col5, #T_46177_row5_col6, #T_46177_row5_col7, #T_46177_row6_col0, #T_46177_row6_col1, #T_46177_row6_col2, #T_46177_row6_col3, #T_46177_row6_col4, #T_46177_row6_col5, #T_46177_row6_col6, #T_46177_row6_col7, #T_46177_row7_col0, #T_46177_row7_col1, #T_46177_row7_col2, #T_46177_row7_col3, #T_46177_row7_col4, #T_46177_row7_col5, #T_46177_row7_col6, #T_46177_row7_col7, #T_46177_row8_col0, #T_46177_row8_col1, #T_46177_row8_col2, #T_46177_row8_col3, #T_46177_row8_col4, #T_46177_row8_col5, #T_46177_row8_col6, #T_46177_row8_col7 {
#   text-align: left;
# }
# #T_46177_row0_col2, #T_46177_row0_col3, #T_46177_row0_col5, #T_46177_row1_col1, #T_46177_row1_col4, #T_46177_row1_col6, #T_46177_row1_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_46177_row0_col8, #T_46177_row1_col8, #T_46177_row2_col8, #T_46177_row3_col8, #T_46177_row4_col8, #T_46177_row6_col8, #T_46177_row7_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_46177_row5_col8, #T_46177_row8_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_46177">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_46177_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_46177_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_46177_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_46177_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_46177_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_46177_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_46177_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_46177_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_46177_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_46177_level0_row0" class="row_heading level0 row0" >qda</th>
#       <td id="T_46177_row0_col0" class="data row0 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_46177_row0_col1" class="data row0 col1" >0.5123</td>
#       <td id="T_46177_row0_col2" class="data row0 col2" >0.5578</td>
#       <td id="T_46177_row0_col3" class="data row0 col3" >0.6914</td>
#       <td id="T_46177_row0_col4" class="data row0 col4" >0.4994</td>
#       <td id="T_46177_row0_col5" class="data row0 col5" >0.5495</td>
#       <td id="T_46177_row0_col6" class="data row0 col6" >0.0247</td>
#       <td id="T_46177_row0_col7" class="data row0 col7" >0.0439</td>
#       <td id="T_46177_row0_col8" class="data row0 col8" >0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_46177_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_46177_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_46177_row1_col1" class="data row1 col1" >0.5309</td>
#       <td id="T_46177_row1_col2" class="data row1 col2" >0.5190</td>
#       <td id="T_46177_row1_col3" class="data row1 col3" >0.5309</td>
#       <td id="T_46177_row1_col4" class="data row1 col4" >0.5420</td>
#       <td id="T_46177_row1_col5" class="data row1 col5" >0.5303</td>
#       <td id="T_46177_row1_col6" class="data row1 col6" >0.0617</td>
#       <td id="T_46177_row1_col7" class="data row1 col7" >0.0626</td>
#       <td id="T_46177_row1_col8" class="data row1 col8" >0.0500</td>
#     </tr>
#     <tr>
#       <th id="T
row0_col0" class="data row0 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_5b1c7_row0_col1" class="data row0 col1" >0.5556</td>
#       <td id="T_5b1c7_row0_col2" class="data row0 col2" >0.5556</td>
#       <td id="T_5b1c7_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_5b1c7_row0_col4" class="data row0 col4" >0.5294</td>
#       <td id="T_5b1c7_row0_col5" class="data row0 col5" >0.6923</td>
#       <td id="T_5b1c7_row0_col6" class="data row0 col6" >0.1111</td>
#       <td id="T_5b1c7_row0_col7" class="data row0 col7" >0.2425</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_596b0_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_596b0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_596b0_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_596b0_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_596b0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_596b0_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_596b0_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_596b0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_596b0_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_596b0_row1_col1" class="data row1 col1" >domain_EI</td>
#     </tr>
#     <tr>
#       <th id="T_596b0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_596b0_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_596b0_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_596b0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_596b0_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_596b0_row3_col1" class="data row3 col1" >(180, 91)</td>
#     </tr>
#     <tr>
#       <th id="T_596b0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_596b0_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_596b0_row4_col1" class="data row4 col1" >(180, 91)</td>
#     </tr>
#     <tr>
#       <th id="T_596b0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_596b0_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_596b0_row5_col1" class="data row5 col1" >(162, 91)</td>
#     </tr>
#     <tr>
#       <th id="T_596b0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_596b0_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_596b0_row6_col1" class="data row6 col1" >(18, 91)</td>
#     </tr>
#     <tr>
#       <th id="T_596b0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_596b0_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_596b0_row7_col1" class="data row7 col1" >90</td>
#     </tr>
#     <tr>
#       <th id="T_596b0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_596b0_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_596b0_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_596b0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_596b0_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_596b0_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_596b0_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_596b0_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_596b0_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_596b0_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_596b0_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_596b0_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_596b0_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_596b0_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_596b0_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_596b0_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_596b0_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_596b0_row13_col1" class="data row13 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_596b0_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_596b0_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_596b0_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_596b0_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_596b0_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_596b0_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_596b0_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_596b0_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_596b0_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_596b0_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_596b0_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_596b0_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_596b0_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_596b0_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_596b0_row18_col1" class="data row18 col1" >6578</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_a00e5 th {
#   text-align: left;
# }
# #T_a00e5_row0_col0, #T_a00e5_row0_col3, #T_a00e5_row0_col5, #T_a00e5_row1_col0, #T_a00e5_row1_col1, #T_a00e5_row1_col2, #T_a00e5_row1_col3, #T_a00e5_row1_col4, #T_a00e5_row1_col5, #T_a00e5_row1_col6, #T_a00e5_row1_col7, #T_a00e5_row2_col0, #T_a00e5_row2_col1, #T_a00e5_row2_col2, #T_a00e5_row2_col3, #T_a00e5_row2_col4, #T_a00e5_row2_col5, #T_a00e5_row2_col6, #T_a00e5_row2_col7, #T_a00e5_row3_col0, #T_a00e5_row3_col1, #T_a00e5_row3_col2, #T_a00e5_row3_col3, #T_a00e5_row3_col4, #T_a00e5_row3_col5, #T_a00e5_row3_col6, #T_a00e5_row3_col7, #T_a00e5_row4_col0, #T_a00e5_row4_col1, #T_a00e5_row4_col2, #T_a00e5_row4_col3, #T_a00e5_row4_col4, #T_a00e5_row4_col5, #T_a00e5_row4_col6, #T_a00e5_row4_col7, #T_a00e5_row5_col0, #T_a00e5_row5_col1, #T_a00e5_row5_col2, #T_a00e5_row5_col3, #T_a00e5_row5_col4, #T_a00e5_row5_col5, #T_a00e5_row5_col6, #T_a00e5_row5_col7, #T_a00e5_row6_col0, #T_a00e5_row6_col1, #T_a00e5_row6_col2, #T_a00e5_row6_col4, #T_a00e5_row6_col6, #T_a00e5_row6_col7, #T_a00e5_row7_col0, #T_a00e5_row7_col1, #T_a00e5_row7_col2, #T_a00e5_row7_col3, #T_a00e5_row7_col4, #T_a00e5_row7_col5, #T_a00e5_row7_col6, #T_a00e5_row7_col7, #T_a00e5_row8_col0, #T_a00e5_row8_col1, #T_a00e5_row8_col2, #T_a00e5_row8_col3, #T_a00e5_row8_col4, #T_a00e5_row8_col5, #T_a00e5_row8_col6, #T_a00e5_row8_col7 {
#   text-align: left;
# }
# #T_a00e5_row0_col1, #T_a00e5_row0_col2, #T_a00e5_row0_col4, #T_a00e5_row0_col6, #T_a00e5_row0_col7, #T_a00e5_row6_col3, #T_a00e5_row6_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_a00e5_row0_col8, #T_a00e5_row1_col8, #T_a00e5_row3_col8, #T_a00e5_row5_col8, #T_a00e5_row7_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_a00e5_row2_col8, #T_a00e5_row4_col8, #T_a00e5_row6_col8, #T_a00e5_row8_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_a00e5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a00e5_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a00e5_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_a00e5_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_a00e5_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_a00e5_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_a00e5_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_a00e5_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_a00e5_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_a00e5_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a00e5_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_a00e5_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_a00e5_row0_col1" class="data row0 col1" >0.5185</td>
#       <td id="T_a00e5_row0_col2" class="data row0 col2" >0.5183</td>
#       <td id="T_a00e5_row0_col3" class="data row0 col3" >0.5185</td>
#       <td id="T_a00e5_row0_col4" class="data row0 col4" >0.5284</td>
#       <td id="T_a00e5_row0_col5" class="data row0 col5" >0.5161</td>
#       <td id="T_a00e5_row0_col6" class="data row0 col6" >0.0370</td>
#       <td id="T_a00e5_row0_col7" class="data row0 col7" >0.0379</td>
#       <td id="T_a00e5_row0_col8" class="data row0 col8" >0.0500</td>
#     </tr>
#     <tr>
#       <th id="T_a00e5_level0_row1" class="row_heading level0 row1" >xgboost</th>
#       <td id="T_a00e5_row1_col0" class="data row1 col0" >Extreme Gradient Boosting</td>
#       <td id="T_a00e5_row1_col1" class="data row1 col1" >0.4815</td>
#       <td id="T_a00e5_row1_col2" class="data row1 col2" >0.5057</td>
#       <td id="T_a00e5_row1_col3" class="data row1 col3" >0.4938</td>
#       <td id="T_a00e5_row1_col4" class="data row1 col4" >0.4879</td>
#       <td id="T_a00e5_row1_col5" class="data row1 col5" >0.4879</td>
#       <td id="T_a00e5_row1_col6" class="data row1 col6" >-0.0370</td>
#       <td id="T_a00e5_row1_col7" class="data row1 col7" >-0.0372</td>
#       <td id="T_a00e5_row1_col8" class="data row1 col8" >0.0800</td>
#     </tr>
#     <tr>
#       <th id="T_a00e5_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_a00e5_row2_col0" class="data row2 col0" >Logistic Regression</td>
#       <td id="T_a00e5_row2_col1" class="data row2 col1" >0.5123</td>
#       <td id="T_a00e5_row2_col2" class="data row2 col2" >0.5007</td>
#       <td id="T_a00e5_row2_col3" class="data row2 col3" >0.4938</td>
#       <td id="T_a00e5_row2_col4" class="data row2 col4" >0.5113</td>
#       <td id="T_a00e5_row2_col5" class="data row2 col5" >0.5023</td>
#       <td id="T_a00e5_row2_col6" class="data row2 col6" >0.0247</td>
#       <td id="T_a00e5_row2_col7" class="data row2 col7" >0.0246</td>
#       <td id="T_a00e5_row2_col8" class="data row2 col8" >0.0067</td>
#     </tr>
#     <tr>
#       <th id="T_a00e5_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_a00e5_row3_col0" class="data row3 col0" >Extra Trees Classifier</td>
#       <td id="T_a00e5_row3_col1" class="data row3 col1" >0.5062</td>
#       <td id="T_a00e5_row3_col2" class="data row3 col2" >0.4995</td>
#       <td id="T_a00e5_row3_col3" class="data row3 col3" >0.4938</td>
#       <td id="T_a00e5_row3_col4" class="data row3 col4" >0.5087</td>
#       <td id="T_a00e5_row3_col5" class="data row3 col5" >0.4983</td>
#       <td id="T_a00e5_row3_col6" class="data row3 col6" >0.0123</td>
#       <td id="T_a00e5_row3_col7" class="data row3 col7" >0.0125</td>
#       <td id="T_a00e5_row3_col8" class="data row3 col8" >0.0400</td>
#     </tr>
#     <tr>
#       <th id="T_a00e5_level0_row4" class="row_heading level0 row4" >svm</th>
#       <td id="T_a00e5_row4_col0" class="data row4 col0" >SVM - Linear Kernel</td>
#       <td id="T_a00e5_row4_col1" class="data row4 col1" >0.4691</td>
#       <td id="T_a00e5_row4_col2" class="data row4 col2" >0.4787</td>
#       <td id="T_a00e5_row4_col3" class="data row4 col3" >0.5062</td>
#       <td id="T_a00e5_row4_col4" class="data row4 col4" >0.4733</td>
#       <td id="T_a00e5_row4_col5" class="data row4 col5" >0.4875</td>
#       <td id="T_a00e5_row4_col6" class="data row4 col6" >-0.0617</td>
#       <td id="T_a00e5_row4_col7" class="data row4 col7" >-0.0635</td>
#       <td id="T_a00e5_row4_col8" class="data row4 col8" >0.0067</td>
#     </tr>
#     <tr>
#       <th id="T_a00e5_level0_row5" class="row_heading level0 row5" >knn</th>
#       <td id="T_a00e5_row5_col0" class="data row5 col0" >K Neighbors Classifier</td>
#       <td id="T_a00e5_row5_col1" class="data row5 col1" >0.5123</td>
#       <td id="T_a00e5_row5_col2" class="data row5 col2" >0.4765</td>
#       <td id="T_a00e5_row5_col3" class="data row5 col3" >0.4815</td>
#       <td id="T_a00e5_row5_col4" class="data row5 col4" >0.5213</td>
#       <td id="T_a00e5_row5_col5" class="data row5 col5" >0.4965</td>
#       <td id="T_a00e5_row5_col6" class="data row5 col6" >0.0247</td>
#       <td id="T_a00e5_row5_col7" class="data row5 col7" >0.0263</td>
#       <td id="T_a00e5_row5_col8" class="data row5 col8" >0.0133</td>
#     </tr>
#     <tr>
#       <th id="T_a00e5_level0_row6" class="row_heading level0 row6" >qda</th>
#       <td id="T_a00e5_row6_col0" class="data row6 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_a00e5_row6_col1" class="data row6 col1" >0.4815</td>
#       <td id="T_a00e5_row6_col2" class="data row6 col2" >0.4668</td>
#       <td id="T_a00e5_row6_col3" class="data row6 col3" >0.6543</td>
#       <td id="T_a00e5_row6_col4" class="data row6 col4" >0.4848</td>
#       <td id="T_a00e5_row6_col5" class="data row6 col5" >0.5547</td>
#       <td id="T_a00e5_row6_col6" class="data row6 col6" >-0.0370</td>
#       <td id="T_a00e5_row6_col7" class="data row6 col7" >-0.0393</td>
#       <td id="T_a00e5_row6_col8" class="data row6 col8" >0.0067</td>
#     </tr>
#     <tr>
#       <th id="T_a00e5_level0_row7" class="row_heading level0 row7" >catboost</th>
#       <td id="T_a00e5_row7_col0" class
# <style type="text/css">
# </style>
# <table id="T_79fb6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_79fb6_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_79fb6_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_79fb6_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_79fb6_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_79fb6_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_79fb6_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_79fb6_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_79fb6_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_79fb6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_79fb6_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_79fb6_row0_col1" class="data row0 col1" >0.2778</td>
#       <td id="T_79fb6_row0_col2" class="data row0 col2" >0.2469</td>
#       <td id="T_79fb6_row0_col3" class="data row0 col3" >0.4444</td>
#       <td id="T_79fb6_row0_col4" class="data row0 col4" >0.3333</td>
#       <td id="T_79fb6_row0_col5" class="data row0 col5" >0.3810</td>
#       <td id="T_79fb6_row0_col6" class="data row0 col6" >-0.4444</td>
#       <td id="T_79fb6_row0_col7" class="data row0 col7" >-0.4714</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_3575b_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_3575b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3575b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_3575b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3575b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3575b_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_3575b_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_3575b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3575b_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_3575b_row1_col1" class="data row1 col1" >domain_EI</td>
#     </tr>
#     <tr>
#       <th id="T_3575b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3575b_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_3575b_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_3575b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3575b_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_3575b_row3_col1" class="data row3 col1" >(180, 91)</td>
#     </tr>
#     <tr>
#       <th id="T_3575b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3575b_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_3575b_row4_col1" class="data row4 col1" >(180, 91)</td>
#     </tr>
#     <tr>
#       <th id="T_3575b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3575b_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_3575b_row5_col1" class="data row5 col1" >(162, 91)</td>
#     </tr>
#     <tr>
#       <th id="T_3575b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3575b_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_3575b_row6_col1" class="data row6 col1" >(18, 91)</td>
#     </tr>
#     <tr>
#       <th id="T_3575b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3575b_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_3575b_row7_col1" class="data row7 col1" >90</td>
#     </tr>
#     <tr>
#       <th id="T_3575b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3575b_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_3575b_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_3575b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3575b_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_3575b_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_3575b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_3575b_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_3575b_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_3575b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_3575b_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_3575b_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_3575b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_3575b_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_3575b_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_3575b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_3575b_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_3575b_row13_col1" class="data row13 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_3575b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_3575b_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_3575b_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_3575b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_3575b_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_3575b_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3575b_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_3575b_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_3575b_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3575b_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_3575b_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_3575b_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_3575b_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_3575b_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_3575b_row18_col1" class="data row18 col1" >7a14</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_f4d9e th {
#   text-align: left;
# }
# #T_f4d9e_row0_col0, #T_f4d9e_row0_col1, #T_f4d9e_row0_col4, #T_f4d9e_row0_col6, #T_f4d9e_row0_col7, #T_f4d9e_row1_col0, #T_f4d9e_row1_col1, #T_f4d9e_row1_col2, #T_f4d9e_row1_col3, #T_f4d9e_row1_col4, #T_f4d9e_row1_col5, #T_f4d9e_row1_col6, #T_f4d9e_row1_col7, #T_f4d9e_row2_col0, #T_f4d9e_row2_col2, #T_f4d9e_row2_col3, #T_f4d9e_row2_col4, #T_f4d9e_row2_col5, #T_f4d9e_row3_col0, #T_f4d9e_row3_col1, #T_f4d9e_row3_col2, #T_f4d9e_row3_col3, #T_f4d9e_row3_col4, #T_f4d9e_row3_col5, #T_f4d9e_row3_col6, #T_f4d9e_row3_col7, #T_f4d9e_row4_col0, #T_f4d9e_row4_col1, #T_f4d9e_row4_col2, #T_f4d9e_row4_col3, #T_f4d9e_row4_col5, #T_f4d9e_row4_col6, #T_f4d9e_row4_col7, #T_f4d9e_row5_col0, #T_f4d9e_row5_col1, #T_f4d9e_row5_col2, #T_f4d9e_row5_col3, #T_f4d9e_row5_col4, #T_f4d9e_row5_col5, #T_f4d9e_row5_col6, #T_f4d9e_row5_col7, #T_f4d9e_row6_col0, #T_f4d9e_row6_col1, #T_f4d9e_row6_col2, #T_f4d9e_row6_col3, #T_f4d9e_row6_col4, #T_f4d9e_row6_col5, #T_f4d9e_row6_col6, #T_f4d9e_row6_col7, #T_f4d9e_row7_col0, #T_f4d9e_row7_col1, #T_f4d9e_row7_col2, #T_f4d9e_row7_col3, #T_f4d9e_row7_col4, #T_f4d9e_row7_col5, #T_f4d9e_row7_col6, #T_f4d9e_row7_col7, #T_f4d9e_row8_col0, #T_f4d9e_row8_col1, #T_f4d9e_row8_col2, #T_f4d9e_row8_col3, #T_f4d9e_row8_col4, #T_f4d9e_row8_col5, #T_f4d9e_row8_col6, #T_f4d9e_row8_col7 {
#   text-align: left;
# }
# #T_f4d9e_row0_col2, #T_f4d9e_row0_col3, #T_f4d9e_row0_col5, #T_f4d9e_row2_col1, #T_f4d9e_row2_col6, #T_f4d9e_row2_col7, #T_f4d9e_row4_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_f4d9e_row0_col8, #T_f4d9e_row1_col8, #T_f4d9e_row3_col8, #T_f4d9e_row6_col8, #T_f4d9e_row7_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_f4d9e_row2_col8, #T_f4d9e_row4_col8, #T_f4d9e_row5_col8, #T_f4d9e_row8_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_f4d9e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f4d9e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f4d9e_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_f4d9e_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_f4d9e_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_f4d9e_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_f4d9e_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_f4d9e_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_f4d9e_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_f4d9e_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f4d9e_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_f4d9e_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_f4d9e_row0_col1" class="data row0 col1" >0.5123</td>
#       <td id="T_f4d9e_row0_col2" class="data row0 col2" >0.5233</td>
#       <td id="T_f4d9e_row0_col3" class="data row0 col3" >0.5062</td>
#       <td id="T_f4d9e_row0_col4" class="data row0 col4" >0.5231</td>
#       <td id="T_f4d9e_row0_col5" class="data row0 col5" >0.5079</td>
#       <td id="T_f4d9e_row0_col6" class="data row0 col6" >0.0247</td>
#       <td id="T_f4d9e_row0_col7" class="data row0 col7" >0.0255</td>
#       <td id="T_f4d9e_row0_col8" class="data row0 col8" >0.0500</td>
#     </tr>
#     <tr>
#       <th id="T_f4d9e_level0_row1" class="row_heading level0 row1" >xgboost</th>
#       <td id="T_f4d9e_row1_col0" class="data row1 col0" >Extreme Gradient Boosting</td>
#       <td id="T_f4d9e_row1_col1" class="data row1 col1" >0.4815</td>
#       <td id="T_f4d9e_row1_col2" class="data row1 col2" >0.5057</td>
#       <td id="T_f4d9e_row1_col3" class="data row1 col3" >0.4938</td>
#       <td id="T_f4d9e_row1_col4" class="data row1 col4" >0.4879</td>
#       <td id="T_f4d9e_row1_col5" class="data row1 col5" >0.4879</td>
#       <td id="T_f4d9e_row1_col6" class="data row1 col6" >-0.0370</td>
#       <td id="T_f4d9e_row1_col7" class="data row1 col7" >-0.0372</td>
#       <td id="T_f4d9e_row1_col8" class="data row1 col8" >0.0233</td>
#     </tr>
#     <tr>
#       <th id="T_f4d9e_level0_row2" class="row_heading level0 row2" >qda</th>
#       <td id="T_f4d9e_row2_col0" class="data row2 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_f4d9e_row2_col1" class="data row2 col1" >0.5309</td>
#       <td id="T_f4d9e_row2_col2" class="data row2 col2" >0.5034</td>
#       <td id="T_f4d9e_row2_col3" class="data row2 col3" >0.4568</td>
#       <td id="T_f4d9e_row2_col4" class="data row2 col4" >0.5421</td>
#       <td id="T_f4d9e_row2_col5" class="data row2 col5" >0.4863</td>
#       <td id="T_f4d9e_row2_col6" class="data row2 col6" >0.0617</td>
#       <td id="T_f4d9e_row2_col7" class="data row2 col7" >0.0661</td>
#       <td id="T_f4d9e_row2_col8" class="data row2 col8" >0.0067</td>
#     </tr>
#     <tr>
#       <th id="T_f4d9e_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_f4d9e_row3_col0" class="data row3 col0" >Extra Trees Classifier</td>
#       <td id="T_f4d9e_row3_col1" class="data row3 col1" >0.5000</td>
#       <td id="T_f4d9e_row3_col2" class="data row3 col2" >0.5005</td>
#       <td id="T_f4d9e_row3_col3" class="data row3 col3" >0.4815</td>
#       <td id="T_f4d9e_row3_col4" class="data row3 col4" >0.5008</td>
#       <td id="T_f4d9e_row3_col5" class="data row3 col5" >0.4874</td>
#       <td id="T_f4d9e_row3_col6" class="data row3 col6" >-0.0000</td>
#       <td id="T_f4d9e_row3_col7" class="data row3 col7" >-0.0001</td>
#       <td id="T_f4d9e_row3_col8" class="data row3 col8" >0.0400</td>
#     </tr>
#     <tr>
#       <th id="T_f4d9e_level0_row4" class="row_heading level0 row4" >svm</th>
#       <td id="T_f4d9e_row4_col0" class="data row4 col0" >SVM - Linear Kernel</td>
#       <td id="T_f4d9e_row4_col1" class="data row4 col1" >0.4815</td>
#       <td id="T_f4d9e_row4_col2" class="data row4 col2" >0.4819</td>
#       <td id="T_f4d9e_row4_col3" class="data row4 col3" >0.4938</td>
#       <td id="T_f4d9e_row4_col4" class="data row4 col4" >0.5723</td>
#       <td id="T_f4d9e_row4_col5" class="data row4 col5" >0.4446</td>
#       <td id="T_f4d9e_row4_col6" class="data row4 col6" >-0.0370</td>
#       <td id="T_f4d9e_row4_col7" class="data row4 col7" >-0.0161</td>
#       <td id="T_f4d9e_row4_col8" class="data row4 col8" >0.0067</td>
#     </tr>
#     <tr>
#       <th id="T_f4d9e_level0_row5" class="row_heading level0 row5" >lr</th>
#       <td id="T_f4d9e_row5_col0" class="data row5 col0" >Logistic Regression</td>
#       <td id="T_f4d9e_row5_col1" class="data row5 col1" >0.5000</td>
#       <td id="T_f4d9e_row5_col2" class="data row5 col2" >0.4701</td>
#       <td id="T_f4d9e_row5_col3" class="data row5 col3" >0.4691</td>
#       <td id="T_f4d9e_row5_col4" class="data row5 col4" >0.4974</td>
#       <td id="T_f4d9e_row5_col5" class="data row5 col5" >0.4787</td>
#       <td id="T_f4d9e_row5_col6" class="data row5 col6" >0.0000</td>
#       <td id="T_f4d9e_row5_col7" class="data row5 col7" >-0.0006</td>
#       <td id="T_f4d9e_row5_col8" class="data row5 col8" >0.0067</td>
#     </tr>
#     <tr>
#       <th id="T_f4d9e_level0_row6" class="row_heading level0 row6" >catboost</th>
#       <td id="T_f4d9e_row6_col0" class="data row6 col0" >CatBoost Classifier</td>
#       <td id="T_f4d9e_row6_col1" class="data row6 col1" >0.4938</td>
#       <td id="T_f4d9e_row6_col2" class="data row6 col2" >0.4668</td>
#       <td id="T_f4d9e_row6_col3" class="data row6 col3" >0.4198</td>
#       <td id="T_f4d9e_row6_col4" class="data row6 col4" >0.5053</td>
#       <td id="T_f4d9e_row6_col5" class="data row6 col5" >0.4479</td>
#       <td id="T_f4d9e_row6_col6" class="data row6 col6" >-0.0123</td>
#       <td id="T_f4d9e_row6_col7" class="data row6 col7" >-0.0089</td>
#       <td id="T_f4d9e_row6_col8" class="data row6 col8" >1.0767</td>
#     </tr>
#     <tr>
#       <th id="T_f4d9e_level0_row7" class="row_heading level0 row7" >knn</th>
#       <td id="T_f4d9e_row7_col0" class
# <style type="text/css">
# </style>
# <table id="T_3c751">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3c751_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3c751_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_3c751_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_3c751_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_3c751_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_3c751_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_3c751_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_3c751_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3c751_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3c751_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_3c751_row0_col1" class="data row0 col1" >0.3333</td>
#       <td id="T_3c751_row0_col2" class="data row0 col2" >0.2222</td>
#       <td id="T_3c751_row0_col3" class="data row0 col3" >0.4444</td>
#       <td id="T
col8" >0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_72955_level0_row4" class="row_heading level0 row4" >xgboost</th>
#       <td id="T_72955_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#       <td id="T_72955_row4_col1" class="data row4 col1" >0.4815</td>
#       <td id="T_72955_row4_col2" class="data row4 col2" >0.4911</td>
#       <td id="T_72955_row4_col3" class="data row4 col3" >0.5062</td>
#       <td id="T_72955_row4_col4" class="data row4 col4" >0.4870</td>
#       <td id="T_72955_row4_col5" class="data row4 col5" >0.4914</td>
#       <td id="T_72955_row4_col6" class="data row4 col6" >-0.0370</td>
#       <td id="T_72955_row4_col7" class="data row4 col7" >-0.0377</td>
#       <td id="T_72955_row4_col8" class="data row4 col8" >0.0300</td>
#     </tr>
#     <tr>
#       <th id="T_72955_level0_row5" class="row_heading level0 row5" >qda</th>
#       <td id="T_72955_row5_col0" class="data row5 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_72955_row5_col1" class="data row5 col1" >0.5062</td>
#       <td id="T_72955_row5_col2" class="data row5 col2" >0.4769</td>
#       <td id="T_72955_row5_col3" class="data row5 col3" >0.4321</td>
#       <td id="T_72955_row5_col4" class="data row5 col4" >0.5139</td>
#       <td id="T_72955_row5_col5" class="data row5 col5" >0.4593</td>
#       <td id="T_72955_row5_col6" class="data row5 col6" >0.0123</td>
#       <td id="T_72955_row5_col7" class="data row5 col7" >0.0165</td>
#       <td id="T_72955_row5_col8" class="data row5 col8" >0.0067</td>
#     </tr>
#     <tr>
#       <th id="T_72955_level0_row6" class="row_heading level0 row6" >knn</th>
#       <td id="T_72955_row6_col0" class="data row6 col0" >K Neighbors Classifier</td>
#       <td id="T_72955_row6_col1" class="data row6 col1" >0.4691</td>
#       <td id="T_72955_row6_col2" class="data row6 col2" >0.4611</td>
#       <td id="T_72955_row6_col3" class="data row6 col3" >0.4321</td>
#       <td id="T_72955_row6_col4" class="data row6 col4" >0.4665</td>
#       <td id="T_72955_row6_col5" class="data row6 col5" >0.4444</td>
#       <td id="T_72955_row6_col6" class="data row6 col6" >-0.0617</td>
#       <td id="T_72955_row6_col7" class="data row6 col7" >-0.0629</td>
#       <td id="T_72955_row6_col8" class="data row6 col8" >0.0067</td>
#     </tr>
#     <tr>
#       <th id="T_72955_level0_row7" class="row_heading level0 row7" >catboost</th>
#       <td id="T_72955_row7_col0" class
# <style type="text/css">
# </style>
# <table id="T_60306">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_60306_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_60306_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_60306_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_60306_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_60306_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_60306_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_60306_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_60306_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_60306_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_60306_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_60306_row0_col1" class="data row0 col1" >0.3889</td>
#       <td id="T_60306_row0_col2" class="data row0 col2" >0.4444</td>
#       <td id="T_60306_row0_col3" class="data row0 col3" >0.4444</td>
#       <td id="T_60306_row0_col4" class="data row0 col4" >0.4000</td>
#       <td id="T_60306_row0_col5" class="data row0 col5" >0.4211</td>
#       <td id="T_60306_row0_col6" class="data row0 col6" >-0.2222</td>
#       <td id="T_60306_row0_col7" class="data row0 col7" >-0.2236</td>
#     </tr>
#   </tbody>
# </table>
# Feature Configs: 100%|██████████| 4/4 [01:09<00:00, 17.40s/it]

# %% [markdown]
# ### Vlnc

# %%
for cfg_id, excl_cols in tqdm(FEATURE_EXCLUDE_SETS.items(),
                              desc="Feature Configs"):

    for scaler_name, scaler in tqdm(SCALERS.items(),
                                    desc=f"Scalers for {cfg_id}",
                                    leave=False):

        # 3-1 ▶ split -------------------------------------------------------
        X = df_vlnc.drop(columns=MUST_EXCLUDE + excl_cols)
        y = df_vlnc[TARGET]
        X_tr, X_te, y_tr, y_te = train_test_split(
            X, y, stratify=y, test_size=0.10, random_state=42
        )

        if X_tr.shape[1] == 0:             # empty feature guard
            print(f"🚫 cfg{cfg_id}|{scaler_name}: no features"); continue

        # 3-2 ▶ optional scaling -------------------------------------------
        if scaler:
            X_tr = pd.DataFrame(scaler.fit_transform(X_tr),
                                index=X_tr.index, columns=X_tr.columns)
            X_te = pd.DataFrame(scaler.transform(X_te),
                                index=X_te.index, columns=X_te.columns)

        # 3-3 ▶ PyCaret setup  --------------------------------------------
        train_df = pd.concat([X_tr.reset_index(drop=True),
                              y_tr.reset_index(drop=True)], axis=1)
        test_df  = pd.concat([X_te.reset_index(drop=True),
                              y_te.reset_index(drop=True)], axis=1)

        setup(
            data=train_df,
            test_data=test_df,     # 👈 pass *your* hold-out here
            target=TARGET,
            session_id=42,
            fold=3,
            use_gpu=False,
            html=True,
            verbose=True,
            feature_selection=False,
            index=False,
        )

        # 3-4 ▶ model search  ---------------------------------------------
        best = compare_models(include=INCLUDE_MODELS,
                              sort="AUC",   fold=3,
                              turbo=False, verbose=True)

        tag = f"cfg{cfg_id}_{scaler_name}"
        best_models_vlnc[tag] = best

        # leaderboard CSV ---------------------------------------------------
        pull().assign(config=cfg_id, scaler=scaler_name) \
              .to_csv(os.path.join(RES_VLNC_PATH, f"leaderboard_{tag}.csv"),
                      index=False)

        # 3-5 ▶ predict on hold-out & plots -------------------------------
        pred = predict_model(best)     # uses test_data provided in setup()

        plot_model(best, plot="confusion_matrix",   save=True)
        os.replace("Confusion Matrix.png",
                   os.path.join(CM_VLNC_PATH,  f"CM_{tag}.png"))

        # AUC — only if model supports probability estimates
        if hasattr(best, "predict_proba"):
            plot_model(best, plot="auc", save=True)
            if os.path.exists("AUC.png"):
                os.replace("AUC.png", os.path.join(AUC_VLNC_PATH, f"AUC_{tag}.png"))
        else:
            print(f"[SKIP] AUC not available for {tag}")

        # 3-6 ▶ feature importance ----------------------------------------
        fi_path = os.path.join(FI_VLNC_PATH, f"FI_{tag}.png")

        def save_fi_tree():
            plot_model(best, plot="feature", save=True)
            os.replace("Feature Importance.png", fi_path)

        if hasattr(best, "feature_importances_"):
            save_fi_tree()

        elif best.__class__.__name__.startswith("CatBoost"):
            fi = best.get_feature_importance()
            top = np.argsort(fi)[::-1][:20]
            plt.figure(figsize=(6, 4))
            plt.barh(range(len(top)), fi[top][::-1])
            plt.yticks(range(len(top)), X_tr.columns[top][::-1])
            plt.tight_layout(); plt.savefig(fi_path); plt.close()

        # 3-7 ▶ collect numeric summary -----------------------------------
        cv_metrics = pull().iloc[0]        # row 0 = best model’s CV stats
        results_vlnc.append({
            "config":      cfg_id,
            "scaler":      scaler_name,
            "model":       best.__class__.__name__,
            "AUC_CV":      cv_metrics["AUC"],
            "Acc_CV":      cv_metrics["Accuracy"],
            "Acc_holdout": (pred[TARGET] == pred["prediction_label"]).mean(),
        })
# Out:
# Feature Configs:   0%|          | 0/4 [00:00<?, ?it/s]
# <style type="text/css">
# #T_9e22a_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9e22a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9e22a_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_9e22a_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9e22a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9e22a_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_9e22a_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_9e22a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9e22a_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_9e22a_row1_col1" class="data row1 col1" >domain_EI</td>
#     </tr>
#     <tr>
#       <th id="T_9e22a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9e22a_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_9e22a_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_9e22a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9e22a_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_9e22a_row3_col1" class="data row3 col1" >(180, 91)</td>
#     </tr>
#     <tr>
#       <th id="T_9e22a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9e22a_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_9e22a_row4_col1" class="data row4 col1" >(180, 91)</td>
#     </tr>
#     <tr>
#       <th id="T_9e22a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9e22a_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_9e22a_row5_col1" class="data row5 col1" >(162, 91)</td>
#     </tr>
#     <tr>
#       <th id="T_9e22a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9e22a_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_9e22a_row6_col1" class="data row6 col1" >(18, 91)</td>
#     </tr>
#     <tr>
#       <th id="T_9e22a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9e22a_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_9e22a_row7_col1" class="data row7 col1" >90</td>
#     </tr>
#     <tr>
#       <th id="T_9e22a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9e22a_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_9e22a_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9e22a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9e22a_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_9e22a_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_9e22a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9e22a_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_9e22a_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_9e22a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_9e22a_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_9e22a_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_9e22a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_9e22a_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_9e22a_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_9e22a_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_9e22a_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_9e22a_row13_col1" class="data row13 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_9e22a_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_9e22a_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_9e22a_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_9e22a_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_9e22a_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_9e22a_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9e22a_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_9e22a_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_9e22a_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9e22a_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_9e22a_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_9e22a_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_9e22a_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_9e22a_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_9e22a_row18_col1" class="data row18 col1" >0e2f</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_21e1f th {
#   text-align: left;
# }
# #T_21e1f_row0_col0, #T_21e1f_row0_col1, #T_21e1f_row0_col3, #T_21e1f_row0_col4, #T_21e1f_row0_col5, #T_21e1f_row0_col6, #T_21e1f_row0_col7, #T_21e1f_row1_col0, #T_21e1f_row1_col2, #T_21e1f_row1_col3, #T_21e1f_row2_col0, #T_21e1f_row2_col1, #T_21e1f_row2_col2, #T_21e1f_row2_col3, #T_21e1f_row2_col4, #T_21e1f_row2_col5, #T_21e1f_row2_col6, #T_21e1f_row2_col7, #T_21e1f_row3_col0, #T_21e1f_row3_col1, #T_21e1f_row3_col2, #T_21e1f_row3_col3, #T_21e1f_row3_col4, #T_21e1f_row3_col5, #T_21e1f_row3_col6, #T_21e1f_row3_col7, #T_21e1f_row4_col0, #T_21e1f_row4_col1, #T_21e1f_row4_col2, #T_21e1f_row4_col3, #T_21e1f_row4_col4, #T_21e1f_row4_col5, #T_21e1f_row4_col6, #T_21e1f_row4_col7, #T_21e1f_row5_col0, #T_21e1f_row5_col1, #T_21e1f_row5_col2, #T_21e1f_row5_col4, #T_21e1f_row5_col5, #T_21e1f_row5_col6, #T_21e1f_row5_col7, #T_21e1f_row6_col0, #T_21e1f_row6_col1, #T_21e1f_row6_col2, #T_21e1f_row6_col3, #T_21e1f_row6_col4, #T_21e1f_row6_col5, #T_21e1f_row6_col6, #T_21e1f_row6_col7, #T_21e1f_row7_col0, #T_21e1f_row7_col1, #T_21e1f_row7_col2, #T_21e1f_row7_col3, #T_21e1f_row7_col4, #T_21e1f_row7_col5, #T_21e1f_row7_col6, #T_21e1f_row7_col7, #T_21e1f_row8_col0, #T_21e1f_row8_col1, #T_21e1f_row8_col2, #T_21e1f_row8_col3, #T_21e1f_row8_col4, #T_21e1f_row8_col5, #T_21e1f_row8_col6, #T_21e1f_row8_col7 {
#   text-align: left;
# }
# #T_21e1f_row0_col2, #T_21e1f_row1_col1, #T_21e1f_row1_col4, #T_21e1f_row1_col5, #T_21e1f_row1_col6, #T_21e1f_row1_col7, #T_21e1f_row5_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_21e1f_row0_col8, #T_21e1f_row5_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_21e1f_row1_col8, #T_21e1f_row2_col8, #T_21e1f_row3_col8, #T_21e1f_row4_col8, #T_21e1f_row6_col8, #T_21e1f_row7_col8, #T_21e1f_row8_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_21e1f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_21e1f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_21e1f_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_21e1f_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_21e1f_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_21e1f_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_21e1f_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_21e1f_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_21e1f_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_21e1f_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_21e1f_level0_row0" class="row_heading level0 row0" >nb</th>
#       <td id="T_21e1f_row0_col0" class="data row0 col0" >Naive Bayes</td>
#       <td id="T_21e1f_row0_col1" class="data row0 col1" >0.5556</td>
#       <td id="T_21e1f_row0_col2" class="data row0 col2" >0.5942</td>
#       <td id="T_21e1f_row0_col3" class="data row0 col3" >0.4321</td>
#       <td id="T_21e1f_row0_col4" class="data row0 col4" >0.5850</td>
#       <td id="T_21e1f_row0_col5" class="data row0 col5" >0.4928</td>
#       <td id="T_21e1f_row0_col6" class="data row0 col6" >0.1111</td>
#       <td id="T_21e1f_row0_col7" class="data row0 col7" >0.1184</td>
#       <td id="T_21e1f_row0_col8" class="data row0 col8" >0.0067</td>
#     </tr>
#     <tr>
#       <th id="T_21e1f_level0_row1" class="row_heading level0 row1" >lr</th>
#       <td id="T_21e1f_row1_col0" class="data row1 col0" >Logistic Regression</td>
#       <td id="T_21e1f_row1_col1" class="data row1 col1" >0.5864</td>
#       <td id="T_21e1f_row1_col2" class="data row1 col2" >0.5693</td>
#       <td id="T_21e1f_row1_col3" class="data row1 col3" >0.6049</td>
#       <td id="T_21e1f_row1_col4" class="data row1 col4" >0.6037</td>
#       <td id="T_21e1f_row1_col5" class="data row1 col5" >0.5897</td>
#       <td id="T_21e1f_row1_col6" class="data row1 col6" >0.1728</td>
#       <td id="T_21e1f_row1_col7" class="data row1 col7" >0.1819</td>
#       <td id="T_21e1f_row1_col8" class="data row1 col8" >0.0167</td>
#     </tr>
#     <tr>
#       <th id="T_21e1f_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_21e1f_row2_col0" class="data row2 col0" >Extra Trees Classifier</td>
#       <td id="T_21e1f_row2_col1" class="data row2 col1" >0.5802</td>
#       <td id="T_21e1f_row2_col2" class="data row2 col2" >0.5670</td>
#       <td id="T_21e1f_row2_col3" class="data row2 col3" >0.5926</td>
#       <td id="T_21e1f_row2_col4" class="data row2 col4" >0.5835</td>
#       <td id="T_21e1f_row2_col5" class="data row2 col5" >0.5843</td>
#       <td id="T_21e1f_row2_col6" class="data row2 col6" >0.1605</td>
#       <td id="T_21e1f_row2_col7" class="data row2 col7" >0.1628</td>
#       <td id="T_21e1f_row2_col8" class="data row2 col8" >0.0400</td>
#     </tr>
#     <tr>
#       <th id="T_21e1f_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_21e1f_row3_col0" class="data row3 col0" >Random Forest Classifier</td>
#       <td id="T_21e1f_row3_col1" class="data row3 col1" >0.5432</td>
#       <td id="T_21e1f_row3_col2" class="data row3 col2" >0.5210</td>
#       <td id="T_21e1f_row3_col3" class="data row3 col3" >0.4815</td>
#       <td id="T_21e1f_row3_col4" class="data row3 col4" >0.5496</td>
#       <td id="T_21e1f_row3_col5" class="data row3 col5" >0.5086</td>
#       <td id="T_21e1f_row3_col6" class="data row3 col6" >0.0864</td>
#       <td id="T_21e1f_row3_col7" class="data row3 col7" >0.0882</td>
#       <td id="T_21e1f_row3_col8" class="data row3 col8" >0.0467</td>
#     </tr>
#     <tr>
#       <th id="T_21e1f_level0_row4" class="row_heading level0 row4" >svm</th>
#       <td id="T_21e1f_row4_col0" class="data row4 col0" >SVM - Linear Kernel</td>
#       <td id="T_21e1f_row4_col1" class="data row4 col1" >0.5062</td>
#       <td id="T_21e1f_row4_col2" class="data row4 col2" >0.5080</td>
#       <td id="T_21e1f_row4_col3" class="data row4 col3" >0.3951</td>
#       <td id="T_21e1f_row4_col4" class="data row4 col4" >0.5060</td>
#       <td id="T_21e1f_row4_col5" class="data row4 col5" >0.4404</td>
#       <td id="T_21e1f_row4_col6" class="data row4 col6" >0.0123</td>
#       <td id="T_21e1f_row4_col7" class="data row4 col7" >0.0122</td>
#       <td id="T_21e1f_row4_col8" class="data row4 col8" >0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_21e1f_level0_row5" class="row_heading level0 row5" >qda</th>
#       <td id="T_21e1f_row5_col0" class="data row5 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_21e1f_row5_col1" class="data row5 col1" >0.5062</td>
#       <td id="T_21e1f_row5_col2" class="data row5 col2" >0.4961</td>
#       <td id="T_21e1f_row5_col3" class="data row5 col3" >0.7284</td>
#       <td id="T_21e1f_row5_col4" class="data row5 col4" >0.4928</td>
#       <td id="T_21e1f_row5_col5" class="data row5 col5" >0.5635</td>
#       <td id="T_21e1f_row5_col6" class="data row5 col6" >0.0123</td>
#       <td id="T_21e1f_row5_col7" class="data row5 col7" >-0.0025</td>
#       <td id="T_21e1f_row5_col8" class="data row5 col8" >0.0067</td>
#     </tr>
#     <tr>
#       <th id="T_21e1f_level0_row6" class="row_heading level0 row6" >catboost</th>
#       <td id="T_21e1f_row6_col0" class="data row6 col0" >CatBoost Classifier</td>
#       <td id="T_21e1f_row6_col1" class="data row6 col1" >0.4753</td>
#       <td id="T_21e1f_row6_col2" class="data row6 col2" >0.4888</td>
#       <td id="T_21e1f_row6_col3" class="data row6 col3" >0.4444</td>
#       <td id="T_21e1f_row6_col4" class="data row6 col4" >0.4667</td>
#       <td id="T_21e1f_row6_col5" class="data row6 col5" >0.4529</td>
#       <td id="T_21e1f_row6_col6" class="data row6 col6" >-0.0494</td>
#       <td id="T_21e1f_row6_col7" class="data row6 col7" >-0.0511</td>
#       <td id="T_21e1f_row6_col8" class="data row6 col8" >0.9067</td>
#     </tr>
#     <tr>
#       <th id="T_21e1f_level0_row7" class="row_heading level0 row7" >knn</th>
#       <td id="T_21e1f_row7_col0" class="data row7 col0" >K Neig
# <style type="text/css">
# </style>
# <table id="T_38425">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_38425_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_38425_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_38425_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_38425_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_38425_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_38425_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_38425_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_38425_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_38425_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_38425_row0_col0" class="data row0 col0" >Naive Bayes</td>
#       <td id="T_38425_row0_col1" class="data row0 col1" >0.5556</td>
#       <td id="T_38425_row0_col2" class="data row0 col2" >0.5741</td>
#       <td id="T_38425_row0_col3" class="data row0 col3" >0.4444</td>
#       <td id="T_38425_row0_col4" class="data row0 col4" >0.5714</td>
#       <td id="T_38425_row0_col5" class="data row0 col5" >0.5000</td>
#       <td id="T_38425_row0_col6" class="data row0 col6" >0.1111</td>
#       <td id="T_38425_row0_col7" class="data row0 col7" >0.1140</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_cf0c3_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_cf0c3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cf0c3_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_cf0c3_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cf0c3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cf0c3_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_cf0c3_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_cf0c3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cf0c3_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_cf0c3_row1_col1" class="data row1 col1" >domain_EI</td>
#     </tr>
#     <tr>
#       <th id="T_cf0c3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cf0c3_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_cf0c3_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_cf0c3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cf0c3_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_cf0c3_row3_col1" class="data row3 col1" >(180, 91)</td>
#     </tr>
#     <tr>
#       <th id="T_cf0c3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cf0c3_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_cf0c3_row4_col1" class="data row4 col1" >(180, 91)</td>
#     </tr>
#     <tr>
#       <th id="T_cf0c3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cf0c3_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_cf0c3_row5_col1" class="data row5 col1" >(162, 91)</td>
#     </tr>
#     <tr>
#       <th id="T_cf0c3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cf0c3_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_cf0c3_row6_col1" class="data row6 col1" >(18, 91)</td>
#     </tr>
#     <tr>
#       <th id="T_cf0c3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_cf0c3_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_cf0c3_row7_col1" class="data row7 col1" >90</td>
#     </tr>
#     <tr>
#       <th id="T_cf0c3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_cf0c3_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_cf0c3_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_cf0c3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_cf0c3_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_cf0c3_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_cf0c3_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_cf0c3_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_cf0c3_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_cf0c3_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_cf0c3_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_cf0c3_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_cf0c3_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_cf0c3_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_cf0c3_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_cf0c3_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_cf0c3_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_cf0c3_row13_col1" class="data row13 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_cf0c3_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_cf0c3_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_cf0c3_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_cf0c3_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_cf0c3_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_cf0c3_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_cf0c3_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_cf0c3_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_cf0c3_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_cf0c3_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_cf0c3_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_cf0c3_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_cf0c3_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_cf0c3_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_cf0c3_row18_col1" class="data row18 col1" >260f</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_59c7d th {
#   text-align: left;
# }
# #T_59c7d_row0_col0, #T_59c7d_row0_col1, #T_59c7d_row0_col3, #T_59c7d_row0_col4, #T_59c7d_row0_col5, #T_59c7d_row0_col6, #T_59c7d_row0_col7, #T_59c7d_row1_col0, #T_59c7d_row1_col1, #T_59c7d_row1_col2, #T_59c7d_row1_col3, #T_59c7d_row1_col4, #T_59c7d_row1_col5, #T_59c7d_row1_col6, #T_59c7d_row1_col7, #T_59c7d_row2_col0, #T_59c7d_row2_col1, #T_59c7d_row2_col2, #T_59c7d_row2_col3, #T_59c7d_row2_col4, #T_59c7d_row2_col5, #T_59c7d_row2_col6, #T_59c7d_row2_col7, #T_59c7d_row3_col0, #T_59c7d_row3_col2, #T_59c7d_row3_col3, #T_59c7d_row3_col5, #T_59c7d_row4_col0, #T_59c7d_row4_col1, #T_59c7d_row4_col2, #T_59c7d_row4_col3, #T_59c7d_row4_col4, #T_59c7d_row4_col5, #T_59c7d_row4_col6, #T_59c7d_row4_col7, #T_59c7d_row5_col0, #T_59c7d_row5_col2, #T_59c7d_row5_col4, #T_59c7d_row5_col7, #T_59c7d_row6_col0, #T_59c7d_row6_col1, #T_59c7d_row6_col2, #T_59c7d_row6_col3, #T_59c7d_row6_col4, #
level0_row3" class="row_heading level0 row3" >knn</th>
#       <td id="T_59c7d_row3_col0" class="data row3 col0" >K Neighbors Classifier</td>
#       <td id="T_59c7d_row3_col1" class="data row3 col1" >0.5802</td>
#       <td id="T_59c7d_row3_col2" class="data row3 col2" >0.5741</td>
#       <td id="T_59c7d_row3_col3" class="data row3 col3" >0.4815</td>
#       <td id="T_59c7d_row3_col4" class="data row3 col4" >0.6014</td>
#       <td id="T_59c7d_row3_col5" class="data row3 col5" >0.5343</td>
#       <td id="T_59c7d_row3_col6" class="data row3 col6" >0.1605</td>
#       <td id="T_59c7d_row3_col7" class="data row3 col7" >0.1642</td>
#       <td id="T_59c7d_row3_col8" class="data row3 col8" >0.0067</td>
#     </tr>
#     <tr>
#       <th id="T_59c7d_level0_row4" class="row_heading level0 row4" >qda</th>
#       <td id="T_59c7d_row4_col0" class="data row4 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_59c7d_row4_col1" class="data row4 col1" >0.5432</td>
#       <td id="T_59c7d_row4_col2" class="data row4 col2" >0.5734</td>
#       <td id="T_59c7d_row4_col3" class="data row4 col3" >0.5062</td>
#       <td id="T_59c7d_row4_col4" class="data row4 col4" >0.5481</td>
#       <td id="T_59c7d_row4_col5" class="data row4 col5" >0.5257</td>
#       <td id="T_59c7d_row4_col6" class="data row4 col6" >0.0864</td>
#       <td id="T_59c7d_row4_col7" class="data row4 col7" >0.0871</td>
#       <td id="T_59c7d_row4_col8" class="data row4 col8" >0.0067</td>
#     </tr>
#     <tr>
#       <th id="T_59c7d_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_59c7d_row5_col0" class="data row5 col0" >Extra Trees Classifier</td>
#       <td id="T_59c7d_row5_col1" class="data row5 col1" >0.5802</td>
#       <td id="T_59c7d_row5_col2" class="data row5 col2" >0.5674</td>
#       <td id="T_59c7d_row5_col3" class="data row5 col3" >0.5926</td>
#       <td id="T_59c7d_row5_col4" class="data row5 col4" >0.5835</td>
#       <td id="T_59c7d_row5_col5" class="data row5 col5" >0.5843</td>
#       <td id="T_59c7d_row5_col6" class="data row5 col6" >0.1605</td>
#       <td id="T_59c7d_row5_col7" class="data row5 col7" >0.1628</td>
#       <td id="T_59c7d_row5_col8" class="data row5 col8" >0.0400</td>
#     </tr>
#     <tr>
#       <th id="T_59c7d_level0_row6" class="row_heading level0 row6" >rf</th>
#       <td id="T_59c7d_row6_col0" class="data row6 col0" >Random Forest Classifier</td>
#       <td id="T_59c7d_row6_col1" class="data row6 col1" >0.5370</td>
#       <td id="T_59c7d_row6_col2" class="data row6 col2" >0.5197</td>
#       <td id="T_59c7d_row6_col3" class="data row6 col3" >0.4691</td>
#       <td id="T_59c7d_row6_col4" class="data row6 col4" >0.5430</td>
#       <td id="T_59c7d_row6_col5" class="data row6 col5" >0.4986</td>
#       <td id="T_59c7d_row6_col6" class="data row6 col6" >0.0741</td>
#       <td id="T_59c7d_row6_col7" class="data row6 col7" >0.0758</td>
#       <td id="T_59c7d_row6_col8" class="data row6 col8" >0.0467</td>
#     </tr>
#     <tr>
#       <th id="T_59c7d_level0_row7" class="row_heading level0 row7" >catboost</th>
#       <td id="T_59c7d_row7_col0" class="data row7 col0" >CatBoo
# <style type="text/css">
# </style>
# <table id="T_311c4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_311c4_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_311c4_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_311c4_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_311c4_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_311c4_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_311c4_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_311c4_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_311c4_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_311c4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_311c4_row0_col0" class="data row0 col0" >SVM - Linear Kernel</td>
#       <td id="T_311c4_row0_col1" class="data row0 col1" >0.6667</td>
#       <td id="T_311c4_row0_col2" class="data row0 col2" >0.6667</td>
#       <td id="T_311c4_row0_col3" class="data row0 col3" >0.6667</td>
#       <td id="T_311c4_row0_col4" class="data row0 col4" >0.6667</td>
#       <td id="T_311c4_row0_col5" class="data row0 col5" >0.6667</td>
#       <td id="T_311c4_row0_col6" class="data row0 col6" >0.3333</td>
#       <td id="T_311c4_row0_col7" class="data row0 col7" >0.3333</td>
#     </tr>
#   </tbody>
# </table>
# Feature Configs:   0%|          | 0/4 [00:10<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 64
#      60 plot_model(best, plot="confusion_matrix",   save=True)
#      61 os.replace("Confusion Matrix.png",
#      62            os.path.join(CM_VLNC_PATH,  f"CM_{tag}.png"))
# ---> 64 plot_model(best, plot="auc",                 save=True)
#      65 os.replace("AUC.png",
#      66            os.path.join(AUC_VLNC_PATH, f"AUC_{tag}.png"))
#      68 # 3-6 ▶ feature importance ----------------------------------------
#
# File ~/miniforge3/envs/etri-emotion/lib/python3.10/site-packages/pycaret/utils/generic.py:964, in check_if_global_is_not_none.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     962     if globals_d[name] is None:
#     963         raise ValueError(message)
# --> 964 return func(*args, **kwargs)
#
# File ~/miniforge3/envs/etri-emotion/lib/python3.10/site-packages/pycaret/classification/functional.py:1725, in plot_model(estimator, plot, scale, save, fold, fit_kwargs, plot_kwargs, groups, verbose, display_format)
#    1611 @check_if_global_is_not_none(globals(), _CURRENT_EXPERIMENT_DECORATOR_DICT)
#    1612 def plot_model(
#    1613     estimator,
#    (...)
#    1622     display_format: Optional[str] = None,
#    1623 ) -> Optional[str]:
#    1624     """
#    1625     This function analyzes the performance of a trained model on holdout set.
#    1626     It may require re-training the model in certain cases.
#    (...)
#    1722
#    1723     """
# -> 1725     return _CURRENT_EXPERIMENT.plot_model(
#    1726         estimator=estimator,
#    1727         plot=plot,
#    1728         scale=scale,
#    1729         save=save,
#    1730         fold=fold,
#    1731         fit_kwargs=fit_kwargs,
#    1732         plot_kwargs=plot_kwargs,
#    1733         groups=groups,
#    1734         verbose=verbose,
#    1735         display_format=display_format,
#    1736     )
#
# File ~/miniforge3/envs/etri-emotion/lib/python3.10/site-packages/pycaret/classification/oop.py:2071, in ClassificationExperiment.plot_model(self, estimator, plot, scale, save, fold, fit_kwargs, plot_kwargs, groups, verbose, display_format)
#    1957 def plot_model(
#    1958     self,
#    1959     estimator,
#    (...)
#    1968     display_format: Optional[str] = None,
#    1969 ) -> Optional[str]:
#    1970     """
#    1971     This function analyzes the performance of a trained model on holdout set.
#    1972     It may require re-training the model in certain cases.
#    (...)
#    2068
#    2069     """
# -> 2071     return super().plot_model(
#    2072         estimator=estimator,
#    2073         plot=plot,
#    2074         scale=scale,
#    2075         save=save,
#    2076         fold=fold,
#    2077         fit_kwargs=fit_kwargs,
#    2078         plot_kwargs=plot_kwargs,
#    2079         groups=groups,
#    2080         verbose=verbose,
#    2081         display_format=display_format,
#    2082     )
#
# File ~/miniforge3/envs/etri-emotion/lib/python3.10/site-packages/pycaret/internal/pycaret_experiment/tabular_experiment.py:2045, in _TabularExperiment.plot_model(self, estimator, plot, scale, save, fold, fit_kwargs, plot_kwargs, groups, feature_name, label, verbose, display_format)
#    1933 def plot_model(
#    1934     self,
#    1935     estimator,
#    (...)
#    1946     display_format: Optional[str] = None,
#    1947 ) -> Optional[str]:
#    1948     """
#    1949     This function takes a trained model object and returns a plot based on the
#    1950     test / hold-out set. The process may require the model to be re-trained in
#    (...)
#    2043
#    2044     """
# -> 2045     return self._plot_model(
#    2046         estimator=estimator,
#    2047         plot=plot,
#    2048         scale=scale,
#    2049         save=save,
#    2050         fold=fold,
#    2051         fit_kwargs=fit_kwargs,
#    2052         plot_kwargs=plot_kwargs,
#    2053         groups=groups,
#    2054         feature_name=feature_name,
#    2055         label=label,
#    2056         verbose=verbose,
#    2057         display_format=display_format,
#    2058     )
#
# File ~/miniforge3/envs/etri-emotion/lib/python3.10/site-packages/pycaret/internal/pycaret_experiment/tabular_experiment.py:439, in _TabularExperiment._plot_model(self, estimator, plot, scale, save, fold, fit_kwargs, plot_kwargs, groups, feature_name, label, verbose, system, display, display_format)
#     431 # exception for CatBoost
#     432 # if "CatBoostClassifier" in str(type(estimator)):
#     433 #    raise ValueError(
#    (...)
#     436
#     437 # checking for auc plot
#     438 if not hasattr(estimator, "predict_proba") and plot == "auc":
# --> 439     raise TypeError(
#     440         "AUC plot not available for estimators with no predict_proba attribute."
#     441     )
#     443 # checking for calibration plot
#     444 if not hasattr(estimator, "predict_proba") and plot == "calibration":
#
# TypeError: AUC plot not available for estimators with no predict_proba attribute.

# %% [markdown]
# ## Step 4. Save overall summary

# %%
results_df = pd.DataFrame(results_multi)
results_df.to_csv(os.path.join(RES_PATH,"overall_results_multi.csv"), index=False)

results_df = pd.DataFrame(results_arsl)
results_df.to_csv(os.path.join(RES_PATH,"overall_results_arsl.csv"), index=False)

results_df = pd.DataFrame(results_vlnc)
results_df.to_csv(os.path.join(RES_PATH,"overall_results_vlnc.csv"), index=False)

# %% [markdown]
# ## 🎯 Selective Outlier Removal Based on XGBoost Feature Importance
#
# Instead of removing all outliers across 88 features, we focus only on the top 10 features identified as most influential for classifying `domain_EI` using XGBoost.
#
# ### Method
#
# - Extract top 10 features with highest importance scores.
# - Apply Z-score based outlier detection (`|Z| > 4`) on those features only.
# - Remove rows where extreme values are detected in these features.
# - Visualize before/after distributions to confirm effective filtering.
#
# This approach ensures:
# - High-impact errors are removed.
# - Valuable data is preserved from non-influential features.

# %%
'''# Step1: Important Features
important_features = [
    'HF', 'lnLF', 'RSA_var', 'LFp_var', 'lnVLF_mssd',
    'HF_var', 'VLFp_mssd', 'rMSSD_autocorr', 'dHz_mssd', 'BPM_autocorr'
]
'''
# Out:
# "# Step1: Important Features\nimportant_features = [\n    'HF', 'lnLF', 'RSA_var', 'LFp_var', 'lnVLF_mssd',\n    'HF_var', 'VLFp_mssd', 'rMSSD_autocorr', 'dHz_mssd', 'BPM_autocorr'\n]\n"

# %%
'''# Step 2. Z-score calculation (Top-10 Imporatant features only) and Z > 4 row detection
z_scores = df[important_features].apply(zscore)

extreme_mask = (np.abs(z_scores) > 4).any(axis=1)
df_outliers = df[extreme_mask]
df_cleaned = df[~extreme_mask].copy()

# Step 3. Remove outliers from the original DataFrame
print(f"⚠️ Rows with Z > 4 in important features: {extreme_mask.sum()} / {len(df)}")
print("Exclude row's name + index:")
display(df_outliers[['name']].reset_index())

print(f"✅ Cleaned data shape: {df_cleaned.shape}")
'''
# Out:
# '# Step 2. Z-score calculation (Top-10 Imporatant features only) and Z > 4 row detection\nz_scores = df[important_features].apply(zscore)\n\nextreme_mask = (np.abs(z_scores) > 4).any(axis=1)\ndf_outliers = df[extreme_mask]\ndf_cleaned = df[~extreme_mask].copy()\n\n# Step 3. Remove outliers from the original DataFrame\nprint(f"⚠️ Rows with Z > 4 in important features: {extreme_mask.sum()} / {len(df)}")\nprint("Exclude row\'s name + index:")\ndisplay(df_outliers[[\'name\']].reset_index())\n\nprint(f"✅ Cleaned data shape: {df_cleaned.shape}")\n'

# %%
'''# Step 4. Plotting the distribution of important features before and after removing outliers
df_before = df[important_features].copy()
df_before['source'] = 'Before'

df_after = df_cleaned[important_features].copy()
df_after['source'] = 'After'

df_plot = pd.concat([df_before, df_after])
df_plot = df_plot.melt(id_vars='source', var_name='feature', value_name='value')

plt.figure(figsize=(20,15))
sns.boxplot(data=df_plot, x='feature', y='value', hue='source')
plt.title("Top Features Distribution: Before vs After Z > 4 Removal")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()'''
# Out:
# '# Step 4. Plotting the distribution of important features before and after removing outliers\ndf_before = df[important_features].copy()\ndf_before[\'source\'] = \'Before\'\n\ndf_after = df_cleaned[important_features].copy()\ndf_after[\'source\'] = \'After\'\n\ndf_plot = pd.concat([df_before, df_after])\ndf_plot = df_plot.melt(id_vars=\'source\', var_name=\'feature\', value_name=\'value\')\n\nplt.figure(figsize=(20,15))\nsns.boxplot(data=df_plot, x=\'feature\', y=\'value\', hue=\'source\')\nplt.title("Top Features Distribution: Before vs After Z > 4 Removal")\nplt.xticks(rotation=45)\nplt.tight_layout()\nplt.show()'
