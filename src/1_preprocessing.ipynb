# %% [markdown]
# # 🎯 Emotion-Domain Classification with PyCaret AutoML (`domain_EI`, 4 classes)
#
# This notebook builds ML classifiers to predict the **emotion-intelligence domain** (`domain_EI`) with four labels
# (HAHV · HALV · LALV · LAHV  →  encoded as 0-3) using **PyCaret 3**.
#
# ---
#
# ## 🧩 Objectives
#
# | Item | Details |
# |------|---------|
# | **Feature sets** | 4 configurations (score_EI / group_EI included or removed) |
# | **Scaling options** | `none`, `standard`, `minmax` |
# | **Model family** | CatBoost · XGBoost · Random Forest · Extra Trees · Logistic Regression · Naive Bayes · SVM · K-NN · QDA |
# | **Total runs** | **12** (4 feature configs × 3 scalers) |
# | **Validation** | Stratified **3-fold CV** inside PyCaret + **20 % hold-out** |
# | **Artifacts** | PNG plots (AUC, confusion matrix, feature importance) + CSV summaries |
#
# ---
#
# ## 🛠️ Pipeline Overview
#
# | Step | Description |
# |------|-------------|
# | **1 — Split** | Apply feature-exclusion rules, then stratified 80 / 20 train-test split |
# | **2 — Scaling** | Transform numeric features with the chosen scaler (`none` / `StandardScaler` / `MinMaxScaler`) |
# | **3 — AutoML** | `compare_models()` evaluates the candidate models via CV and returns the best estimator |
# | **4 — Hold-out Evaluation** | Predict on the reserved test set; save confusion-matrix & AUC plots |
# | **5 — Result Logging** | Collect CV AUC / Accuracy and hold-out Accuracy for each run into a master CSV |
#
# ---
#
# ## 📂 Output Artifacts
#
# | File / Folder | Contents |
# |---------------|----------|
# | **`overall_results.csv`** | One-row summary per run (feature cfg · scaler · chosen model · metrics) |
# | **`leaderboard_cfg*_*.csv`** | Full PyCaret leaderboard (all models, CV statistics) |
# | **`CM_/`, `AUC_/`, `FI_/`** | Confusion-matrix, AUC curve and feature-importance PNGs named by run tag |
# | *(optional)* `best_models.pkl` | Serialized best estimators via `joblib.dump()` |
#
# ---
#
# ## 🔧 Requirements
#
# * **PyCaret 3.x** (classification module)
# * `scikit-learn`, `pandas`, `numpy`, `matplotlib`, `tqdm`
# * CatBoost & XGBoost are pulled automatically with the full PyCaret install
#
# > **Note**
# > * All stimulus-related (`Arousal`, `Valence`, etc.) and subjective self-report variables are **permanently excluded** from the feature space.
# > * The four feature configurations are designed to measure the impact of **EI score** (`score_EI`) and **EI group label** (`group_EI`) on model performance.
# > * GPU acceleration, SHAP explanations and 5-fold CV are **not** used in the current pipeline; they can be added later if needed.

# %% [markdown]
# ## Import Libraries

# %%
# ---------------------------------------------------------------
#  ❖  CONFIG & PREP
# ---------------------------------------------------------------
import os, sys, types, re, joblib, warnings

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, roc_auc_score
from sklearn.ensemble import ExtraTreesClassifier          # used for FS
from pycaret.classification import *
warnings.filterwarnings("ignore", category=UserWarning)

from scipy.stats import zscore
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %% [markdown]
# ## Step 0: Define Save Paths
#
# We define clean, relative paths for all outputs such as feature importance plots, evaluation plots, and CSV results.

# %%
# Base directory: project root (current notebook folder)
ROOT_PATH = os.getcwd()
RES_PATH = os.path.join(ROOT_PATH, '../res')

# DATA
DATA_PATH = os.path.join(os.getcwd(), '../data/')
EXCEL_PATH = "../data/ETRI_cardiac.xlsx"
CSV_PATH = "../data/ETRI_cardiac.csv"
DF_PATH = "../data/updated_data.csv"

# Define subfolders for saving results
FI_PATH   = os.path.join(RES_PATH, 'FI_plots')      # Feature Importance
CM_PATH   = os.path.join(RES_PATH, 'CM_plots')      # Confusion Matrix
AUC_PATH  = os.path.join(RES_PATH, 'AUC_plots')     # AUC Curves
SHAP_PATH = os.path.join(RES_PATH, 'SHAP_plots')    # SHAP Plots
RES_CSV_PATH  = os.path.join(RES_PATH, 'results_csv')   # CSV files

# Create directories if they don't exist
for path in [FI_PATH, CM_PATH, AUC_PATH, SHAP_PATH, RES_CSV_PATH]:
    os.makedirs(path, exist_ok=True)

# %%
df = pd.read_csv(DF_PATH)
df.head()
# Out:
#          name  year  score_EI  domain_EI  trainnig  group_EI  자극_Arousal  \
# 0  subj_01_00  2021       400          0         0         0           1
# 1  subj_01_01  2021       400          1         0         0           1
# 2  subj_01_02  2021       400          3         0         0           0
# 3  subj_01_03  2021       400          2         0         0           0
# 4  subj_02_00  2021       450          0         0         0           1
#
#    자극_Valence  Arousal  Valence  ...  VLF/HF_autocorr  LF/HF_autocorr  \
# 0           1        4        5  ...        -0.567119       -0.991761
# 1           0        6        4  ...        -2.854562       -1.532805
# 2           1        3        6  ...        -1.375726       -1.030548
# 3           0        4        4  ...        -0.198272        0.921968
# 4           1        6        7  ...         0.469754        0.216407
#
#    tPow_autocorr  dPow_autocorr  dHz_autocorr  pPow_autocorr  pHz_autocorr  \
# 0       4.761754      -0.106286     -0.597611      -0.177651     -1.020465
# 1      -4.013737      13.465573     -1.486156       0.136173     -0.504705
# 2       0.056760      -1.111399     -1.126756      -0.961825     -1.626310
# 3      -2.812514       7.058668     -0.880433      -0.866042     -0.602454
# 4       0.900575       0.121397      0.023057      -0.702703     -0.874824
#
#    CohRatio_autocorr  RSA_autocorr  dHz_diff_autocorr
# 0          -1.087973      1.085212          -0.595462
# 1          -0.481968      0.855739          -1.486156
# 2          -1.110674     -0.670813          -1.127433
# 3          -1.700471      0.168826          -0.880433
# 4           0.579896     -0.289846           0.023057
#
# [5 rows x 100 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 100 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               180 non-null    object
#  1   year               180 non-null    int64
#  2   score_EI           180 non-null    int64
#  3   domain_EI          180 non-null    int64
#  4   trainnig           180 non-null    int64
#  5   group_EI           180 non-null    int64
#  6   자극_Arousal         180 non-null    int64
#  7   자극_Valence         180 non-null    int64
#  8   Arousal            180 non-null    int64
#  9   Valence            180 non-null    int64
#  10  Subj_AR            180 non-null    int64
#  11  Subj_PN            180 non-null    int64
#  12  BPM                180 non-null    float64
#  13  SDNN               180 non-null    float64
#  14  rMSSD              180 non-null    float64
#  15  VLF                180 non-null    float64
#  16  LF                 180 non-null    float64
#  17  HF                 180 non-null    float64
#  18  VLFp               180 non-null    float64
#  19  LFp                180 non-null    float64
#  20  HFp                180 non-null    float64
#  21  lnVLF              180 non-null    float64
#  22  lnLF               180 non-null    float64
#  23  lnHF               180 non-null    float64
#  24  VLF/HF             180 non-null    float64
#  25  LF/HF              180 non-null    float64
#  26  tPow               180 non-null    float64
#  27  dPow               180 non-null    float64
#  28  dHz                180 non-null    float64
#  29  pPow               180 non-null    float64
#  30  pHz                180 non-null    float64
#  31  CohRatio           180 non-null    float64
#  32  RSA_PB             180 non-null    float64
#  33  tpow_diff          180 non-null    float64
#  34  BPM_var            180 non-null    float64
#  35  SDNN_var           180 non-null    float64
#  36  rMSSD_var          180 non-null    float64
#  37  VLF_var            180 non-null    float64
#  38  LF_var             180 non-null    float64
#  39  HF_var             180 non-null    float64
#  40  VLFp_var           180 non-null    float64
#  41  LFp_var            180 non-null    float64
#  42  HFp_var            180 non-null    float64
#  43  lnVLF_var          180 non-null    float64
#  44  lnLF_var           180 non-null    float64
#  45  lnHF_var           180 non-null    float64
#  46  VLF/HF_var         180 non-null    float64
#  47  LF/HF_var          180 non-null    float64
#  48  tPow_var           180 non-null    float64
#  49  dPow_var           180 non-null    float64
#  50  dHz_var            180 non-null    float64
#  51  pPow_var           180 non-null    float64
#  52  pHz_var            180 non-null    float64
#  53  CohRatio_var       180 non-null    float64
#  54  RSA_var            180 non-null    float64
#  55  dHz_diff_var       180 non-null    float64
#  56  BPM_mssd           180 non-null    float64
#  57  SDNN_mssd          180 non-null    float64
#  58  rMSSD_mssd         180 non-null    float64
#  59  VLF_mssd           180 non-null    float64
#  60  LF_mssd            180 non-null    float64
#  61  HF_mssd            180 non-null    float64
#  62  VLFp_mssd          180 non-null    float64
#  63  LFp_mssd           180 non-null    float64
#  64  HFp_mssd           180 non-null    float64
#  65  lnVLF_mssd         180 non-null    float64
#  66  lnLF_mssd          180 non-null    float64
#  67  lnHF_mssd          180 non-null    float64
#  68  VLF/HF_mssd        180 non-null    float64
#  69  LF/HF_mssd         180 non-null    float64
#  70  tPow_mssd          180 non-null    float64
#  71  dPow_mssd          180 non-null    float64
#  72  dHz_mssd           180 non-null    float64
#  73  pPow_mssd          180 non-null    float64
#  74  pHz_mssd           180 non-null    float64
#  75  CohRatio_mssd      180 non-null    float64
#  76  RSA_mssd           180 non-null    float64
#  77  dHz_diff_mssd      180 non-null    float64
#  78  BPM_autocorr       180 non-null    float64
#  79  SDNN_autocorr      180 non-null    float64
#  80  rMSSD_autocorr     180 non-null    float64
#  81  VLF_autocorr       180 non-null    float64
#  82  LF_autocorr        180 non-null    float64
#  83  HF_autocorr        180 non-null    float64
#  84  VLFp_autocorr      180 non-null    float64
#  85  LFp_autocorr       180 non-null    float64
#  86  HFp_autocorr       180 non-null    float64
#  87  lnVLF_autocorr     180 non-null    float64
#  88  lnLF_autocorr      180 non-null    float64
#  89  lnHF_autocorr      180 non-null    float64
#  90  VLF/HF_autocorr    180 non-null    float64
#  91  LF/HF_autocorr     180 non-null    float64
#  92  tPow_autocorr      180 non-null    float64
#  93  dPow_autocorr      180 non-null    float64
#  94  dHz_autocorr       180 non-null    float64
#  95  pPow_autocorr      180 non-null    float64
#  96  pHz_autocorr       180 non-null    float64
#  97  CohRatio_autocorr  180 non-null    float64
#  98  RSA_autocorr       180 non-null    float64
#  99  dHz_diff_autocorr  180 non-null    float64
# dtypes: float64(88), int64(11), object(1)
# memory usage: 140.8+ KB

# %% [markdown]
# ## Step 1: Experiment Settings
# Define Scaling and Setup for PyCaret
#
# We define three types of scaling: none, standard, and min-max, for every feature configuration.

# %%
TARGET = "domain_EI"

# Columns that are never used as features
MUST_EXCLUDE = [
    "name", "domain_EI", "year", "trainnig",
    "Arousal", "Valence", "자극_Arousal", "자극_Valence",
    "Subj_AR", "Subj_PN"
]

# 4 feature-set flavours: keep / drop EI score / drop EI group / drop both
FEATURE_EXCLUDE_SETS = {
    1: [],
    2: ["group_EI"],
    3: ["score_EI"],
    4: ["score_EI", "group_EI"],
}

# Three scaler options
SCALERS = {
    "none":     None,
    "standard": StandardScaler(),
    "minmax":   MinMaxScaler(),
}

# Models we allow PyCaret to try
INCLUDE_MODELS = [
    "catboost", "xgboost", "rf", "et",
    "lr", "nb", "svm", "knn", "qda",
]

# %% [markdown]
# ####  LightGBM stub

# %%
lgb_stub = types.ModuleType("lightgbm")

class _DummyLGBM:
    """Minimal fake LightGBM estimator so that PyCaret can import it."""
    def __init__(self, *args, **kwargs): pass
    def fit(self, *args, **kwargs): return self
    def predict(self, X, *args, **kwargs):          # label output
        return np.zeros(len(X), dtype=int)
    def predict_proba(self, X, *args, **kwargs):    # proba output
        # return 2-col dummy probs for binary; PyCaret only checks shape
        return np.zeros((len(X), 2), dtype=float)

# expose expected symbols at top level
lgb_stub.LGBMClassifier = _DummyLGBM
lgb_stub.LGBMRegressor  = _DummyLGBM
lgb_stub.Dataset        = object          # rarely used by PyCaret

basic_stub = types.ModuleType("lightgbm.basic")
basic_stub.LightGBMError = RuntimeError    # any Exception subclass works

# make `from lightgbm.basic import LightGBMError` succeed
sys.modules["lightgbm.basic"] = basic_stub

# attach sub-module to the parent package stub
lgb_stub.basic = basic_stub

sys.modules["lightgbm"] = lgb_stub

# %% [markdown]
# ## Step 2. Result Containers

# %%
results:     list[dict]        = []     # one row per config+scaler
best_models: dict[str, object] = {}     # tag ➜ fitted model

# %% [markdown]
# ## Step 3: AutoML Training using PyCaret + tqdm Progress Tracking
# WITHOUT OUTLIER vs WITH OUTLIER !! (With Outlier first)
#
# We train models using PyCaret with GPU acceleration, over 8 × 3 configuration combinations.

# %%
'''
for config_id, exclude_cols in tqdm(feature_exclude_sets.items(), desc="Feature Configs", position=0):
    for scaler_name, scaler in tqdm(scalers.items(), desc=f"Scalers for Config {config_id}", leave=False, position=1):
        df_exp = df.copy()
        all_excluded = must_exclude + exclude_cols
        
        remaining_cols = [col for col in df_exp.columns if col not in all_excluded]
        if len(remaining_cols) == 0:
            print(f"⚠️ Skipping config {config_id} + scaler {scaler_name} – no features left.")
            continue

        X = df_exp.drop(columns=all_excluded)
        y = df_exp[target]

        X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=42)

        # ✅ Feature Check
        print(f"\n📌 Config {config_id} | Scaler: {scaler_name}")
        print(f"🔸 X_train shape: {X_train.shape}")
        print(f"🔸 Feature columns: {list(X_train.columns)}")
        print(f"🔸 Null values:\n{X_train.isnull().sum()}")
        print(f"🔸 Class distribution:\n{y_train.value_counts()}")
        print("-" * 60)
'''
# Out:
# '\nfor config_id, exclude_cols in tqdm(feature_exclude_sets.items(), desc="Feature Configs", position=0):\n    for scaler_name, scaler in tqdm(scalers.items(), desc=f"Scalers for Config {config_id}", leave=False, position=1):\n        df_exp = df.copy()\n        all_excluded = must_exclude + exclude_cols\n        \n        remaining_cols = [col for col in df_exp.columns if col not in all_excluded]\n        if len(remaining_cols) == 0:\n            print(f"⚠️ Skipping config {config_id} + scaler {scaler_name} – no features left.")\n            continue\n\n        X = df_exp.drop(columns=all_excluded)\n        y = df_exp[target]\n\n        X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=42)\n\n        # ✅ Feature Check\n        print(f"\n📌 Config {config_id} | Scaler: {scaler_name}")\n        print(f"🔸 X_train shape: {X_train.shape}")\n        print(f"🔸 Feature columns: {list(X_train.columns)}")\n        print(f"🔸 Null values:\n{X_train.isnull().sum()}")\n        print(f"🔸 Class distribution:\n{y_train.value_counts()}")\n        print("-" * 60)\n'

# %% [markdown]
# ### Step 2.3. Experiment loop

# %%
for cfg_id, excl_cols in tqdm(FEATURE_EXCLUDE_SETS.items(),
                              desc="Feature Configs"):

    for scaler_name, scaler in tqdm(SCALERS.items(),
                                    desc=f"Scalers for {cfg_id}",
                                    leave=False):

        # 3-1 ▶ split -------------------------------------------------------
        X = df.drop(columns=MUST_EXCLUDE + excl_cols)
        y = df[TARGET]
        X_tr, X_te, y_tr, y_te = train_test_split(
            X, y, stratify=y, test_size=0.20, random_state=42
        )

        if X_tr.shape[1] == 0:             # empty feature guard
            print(f"🚫 cfg{cfg_id}|{scaler_name}: no features"); continue

        # 3-2 ▶ optional scaling -------------------------------------------
        if scaler:
            X_tr = pd.DataFrame(scaler.fit_transform(X_tr),
                                index=X_tr.index, columns=X_tr.columns)
            X_te = pd.DataFrame(scaler.transform(X_te),
                                index=X_te.index, columns=X_te.columns)

        # 3-3 ▶ PyCaret setup  --------------------------------------------
        train_df = pd.concat([X_tr.reset_index(drop=True),
                              y_tr.reset_index(drop=True)], axis=1)
        test_df  = pd.concat([X_te.reset_index(drop=True),
                              y_te.reset_index(drop=True)], axis=1)

        setup(
            data=train_df,
            test_data=test_df,     # 👈 pass *your* hold-out here
            target=TARGET,
            session_id=42,
            fold=3,
            use_gpu=False,
            html=True,
            verbose=True,
            feature_selection=False,
            index=False,
        )

        # 3-4 ▶ model search  ---------------------------------------------
        best = compare_models(include=INCLUDE_MODELS,
                              sort="AUC",   fold=3,
                              turbo=False, verbose=True)

        tag = f"cfg{cfg_id}_{scaler_name}"
        best_models[tag] = best

        # leaderboard CSV ---------------------------------------------------
        pull().assign(config=cfg_id, scaler=scaler_name) \
              .to_csv(os.path.join(RES_CSV_PATH, f"leaderboard_{tag}.csv"),
                      index=False)

        # 3-5 ▶ predict on hold-out & plots -------------------------------
        pred = predict_model(best)     # uses test_data provided in setup()

        plot_model(best, plot="confusion_matrix",   save=True)
        os.replace("Confusion Matrix.png",
                   os.path.join(CM_PATH,  f"CM_{tag}.png"))

        plot_model(best, plot="auc",                 save=True)
        os.replace("AUC.png",
                   os.path.join(AUC_PATH, f"AUC_{tag}.png"))

        # 3-6 ▶ feature importance ----------------------------------------
        fi_path = os.path.join(FI_PATH, f"FI_{tag}.png")

        def save_fi_tree():
            plot_model(best, plot="feature", save=True)
            os.replace("Feature Importance.png", fi_path)

        if hasattr(best, "feature_importances_"):
            save_fi_tree()

        elif best.__class__.__name__.startswith("CatBoost"):
            fi = best.get_feature_importance()
            top = np.argsort(fi)[::-1][:20]
            plt.figure(figsize=(6, 4))
            plt.barh(range(len(top)), fi[top][::-1])
            plt.yticks(range(len(top)), X_tr.columns[top][::-1])
            plt.tight_layout(); plt.savefig(fi_path); plt.close()

        # 3-7 ▶ collect numeric summary -----------------------------------
        cv_metrics = pull().iloc[0]        # row 0 = best model’s CV stats
        results.append({
            "config":      cfg_id,
            "scaler":      scaler_name,
            "model":       best.__class__.__name__,
            "AUC_CV":      cv_metrics["AUC"],
            "Acc_CV":      cv_metrics["Accuracy"],
            "Acc_holdout": (pred[TARGET] == pred["prediction_label"]).mean(),
        })
# Out:
# Feature Configs:   0%|          | 0/4 [00:00<?, ?it/s]
# <style type="text/css">
# #T_cb854_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_cb854">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb854_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_cb854_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb854_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cb854_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_cb854_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_cb854_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cb854_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_cb854_row1_col1" class="data row1 col1" >domain_EI</td>
#     </tr>
#     <tr>
#       <th id="T_cb854_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cb854_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_cb854_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_cb854_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cb854_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_cb854_row3_col1" class="data row3 col1" >(180, 91)</td>
#     </tr>
#     <tr>
#       <th id="T_cb854_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cb854_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_cb854_row4_col1" class="data row4 col1" >(180, 91)</td>
#     </tr>
#     <tr>
#       <th id="T_cb854_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cb854_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_cb854_row5_col1" class="data row5 col1" >(144, 91)</td>
#     </tr>
#     <tr>
#       <th id="T_cb854_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cb854_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_cb854_row6_col1" class="data row6 col1" >(36, 91)</td>
#     </tr>
#     <tr>
#       <th id="T_cb854_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_cb854_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_cb854_row7_col1" class="data row7 col1" >90</td>
#     </tr>
#     <tr>
#       <th id="T_cb854_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_cb854_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_cb854_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_cb854_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_cb854_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_cb854_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_cb854_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_cb854_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_cb854_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_cb854_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_cb854_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_cb854_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_cb854_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_cb854_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_cb854_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_cb854_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_cb854_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_cb854_row13_col1" class="data row13 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_cb854_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_cb854_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_cb854_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_cb854_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_cb854_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_cb854_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_cb854_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_cb854_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_cb854_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_cb854_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_cb854_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_cb854_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_cb854_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_cb854_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_cb854_row18_col1" class="data row18 col1" >c27e</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_944b9 th {
#   text-align: left;
# }
# #T_944b9_row0_col0, #T_944b9_row0_col1, #T_944b9_row0_col3, #T_944b9_row0_col4, #T_944b9_row0_col5, #T_944b9_row0_col6, #T_944b9_row0_col7, #T_944b9_row1_col0, #T_944b9_row1_col1, #T_944b9_row1_col2, #T_944b9_row1_col3, #T_944b9_row1_col4, #T_944b9_row1_col5, #T_944b9_row1_col6, #T_944b9_row1_col7, #T_944b9_row2_col0, #T_944b9_row2_col1, #T_944b9_row2_col2, #T_944b9_row2_col3, #T_944b9_row2_col4, #T_944b9_row2_col5, #T_944b9_row2_col6, #T_944b9_row2_col7, #T_944b9_row3_col0, #T_944b9_row3_col1, #T_944b9_row3_col2, #T_944b9_row3_col3, #T_944b9_row3_col4, #T_944b9_row3_col5, #T_944b9_row3_col6, #T_944b9_row3_col7, #T_944b9_row4_col0, #T_944b9_row4_col1, #T_944b9_row4_col2, #T_944b9_row4_col3, #T_944b9_row4_col4, #T_944b9_row4_col5, #T_944b9_row4_col6, #T_944b9_row4_col7, #T_944b9_row5_col0, #T_944b9_row5_col1, #T_944b9_row5_col2, #T_944b9_row5_col3, #T_944b9_row5_col4, #T_944b9_row5_col5, #T_944b9_row5_col6, #T_944b9_row5_col7, #T_944b9_row6_col0, #T_944b9_row6_col2, #T_944b9_row7_col0, #T_944b9_row7_col1, #T_944b9_row7_col2, #T_944b9_row7_col3, #T_944b9_row7_col4, #T_944b9_row7_col5, #T_944b9_row7_col6, #T_944b9_row7_col7, #T_944b9_row8_col0, #T_944b9_row8_col1, #T_944b9_row8_col2, #T_944b9_row8_col3, #T_944b9_row8_col4, #T_944b9_row8_col5, #T_944b9_row8_col6, #T_944b9_row8_col7 {
#   text-align: left;
# }
# #T_944b9_row0_col2, #T_944b9_row6_col1, #T_944b9_row6_col3, #T_944b9_row6_col4, #T_944b9_row6_col5, #T_944b9_row6_col6, #T_944b9_row6_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_944b9_row0_col8, #T_944b9_row2_col8, #T_944b9_row3_col8, #T_944b9_row4_col8, #T_944b9_row5_col8, #T_944b9_row6_col8, #T_944b9_row7_col8, #T_944b9_row8_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_944b9_row1_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_944b9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_944b9_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_944b9_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_944b9_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_944b9_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_944b9_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_944b9_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_944b9_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_944b9_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_944b9_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_944b9_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_944b9_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_944b9_row0_col1" class="data row0 col1" >0.2917</td>
#       <td id="T_944b9_row0_col2" class="data row0 col2" >0.5221</td>
#       <td id="T_944b9_row0_col3" class="data row0 col3" >0.2917</td>
#       <td id="T_944b9_row0_col4" class="data row0 col4" >0.2868</td>
#       <td id="T_944b9_row0_col5" class="data row0 col5" >0.2826</td>
#       <td id="T_944b9_row0_col6" class="data row0 col6" >0.0556</td>
#       <td id="T_944b9_row0_col7" class="data row0 col7" >0.0562</td>
#       <td id="T_944b9_row0_col8" class="data row0 col8" >0.0400</td>
#     </tr>
#     <tr>
#       <th id="T_944b9_level0_row1" class="row_heading level0 row1" >nb</th>
#       <td id="T_944b9_row1_col0" class="data row1 col0" >Naive Bayes</td>
#       <td id="T_944b9_row1_col1" class="data row1 col1" >0.2569</td>
#       <td id="T_944b9_row1_col2" class="data row1 col2" >0.4947</td>
#       <td id="T_944b9_row1_col3" class="data row1 col3" >0.2569</td>
#       <td id="T_944b9_row1_col4" class="data row1 col4" >0.2322</td>
#       <td id="T_944b9_row1_col5" class="data row1 col5" >0.2401</td>
#       <td id="T_944b9_row1_col6" class="data row1 col6" >0.0093</td>
#       <td id="T_944b9_row1_col7" class="data row1 col7" >0.0088</td>
#       <td id="T_944b9_row1_col8" class="data row1 col8" >0.0067</td>
#     </tr>
#     <tr>
#       <th id="T_944b9_level0_row2" class="row_heading level0 row2" >xgboost</th>
#       <td id="T_944b9_row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#       <td id="T_944b9_row2_col1" class="data row2 col1" >0.2014</td>
#       <td id="T_944b9_row2_col2" class="data row2 col2" >0.4500</td>
#       <td id="T_944b9_row2_col3" class="data row2 col3" >0.2014</td>
#       <td id="T_944b9_row2_col4" class="data row2 col4" >0.1848</td>
#       <td id="T_944b9_row2_col5" class="data row2 col5" >0.1887</td>
#       <td id="T_944b9_row2_col6" class="data row2 col6" >-0.0648</td>
#       <td id="T_944b9_row2_col7" class="data row2 col7" >-0.0667</td>
#       <td id="T_944b9_row2_col8" class="data row2 col8" >0.2933</td>
#     </tr>
#     <tr>
#       <th id="T_944b9_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_944b9_row3_col0" class="data row3 col0" >Random Forest Classifier</td>
#       <td id="T_944b9_row3_col1" class="data row3 col1" >0.1944</td>
#       <td id="T_944b9_row3_col2" class="data row3 col2" >0.4409</td>
#       <td id="T_944b9_row3_col3" class="data row3 col3" >0.1944</td>
#       <td id="T_944b9_row3_col4" class="data row3 col4" >0.1936</td>
#       <td id="T_944b9_row3_col5" class="data row3 col5" >0.1928</td>
#       <td id="T_944b9_row3_col6" class="data row3 col6" >-0.0741</td>
#       <td id="T_944b9_row3_col7" class="data row3 col7" >-0.0746</td>
#       <td id="T_944b9_row3_col8" class="data row3 col8" >0.0500</td>
#     </tr>
#     <tr>
#       <th id="T_944b9_level0_row4" class="row_heading level0 row4" >knn</th>
#       <td id="T_944b9_row4_col0" class="data row4 col0" >K Neighbors Classifier</td>
#       <td id="T_944b9_row4_col1" class="data row4 col1" >0.1875</td>
#       <td id="T_944b9_row4_col2" class="data row4 col2" >0.4272</td>
#       <td id="T_944b9_row4_col3" class="data row4 col3" >0.1875</td>
#       <td id="T_944b9_row4_col4" class="data row4 col4" >0.1708</td>
#       <td id="T_944b9_row4_col5" class="data row4 col5" >0.1748</td>
#       <td id="T_944b9_row4_col6" class="data row4 col6" >-0.0833</td>
#       <td id="T_944b9_row4_col7" class="data row4 col7" >-0.0844</td>
#       <td id="T_944b9_row4_col8" class="data row4 col8" >0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_944b9_level0_row5" class="row_heading level0 row5" >catboost</th>
#       <td id="T_944b9_row5_col0" class="data row5 col0" >CatBoost Classifier</td>
#       <td id="T_944b9_row5_col1" class="data row5 col1" >0.1875</td>
#       <td id="T_944b9_row5_col2" class="data row5 col2" >0.4267</td>
#       <td id="T_944b9_row5_col3" class="data row5 col3" >0.1875</td>
#       <td id="T_944b9_row5_col4" class="data row5 col4" >0.1826</td>
#       <td id="T_944b9_row5_col5" class="data row5 col5" >0.1804</td>
#       <td id="T_944b9_row5_col6" class="data row5 col6" >-0.0833</td>
#       <td id="T_944b9_row5_col7" class="data row5 col7" >-0.0835</td>
#       <td id="T_944b9_row5_col8" class="data row5 col8" >2.6200</td>
#     </tr>
#     <tr>
#       <th id="T_944b9_level0_row6" class="row_heading level0 row6" >lr</th>
#       <td id="T_944b9_row6_col0" class="data row6 col0" >Logistic Regression</td>
#       <td id="T_944b9_row6_col1" class="data row6 col1" >0.3125</td>
#       <td id="T_944b9_row6_col2" class="data row6 col2" >0.0000</td>
#       <td id="T_944b9_row6_col3" class="data row6 col3" >0.3125</td>
#       <td id="T_944b9_row6_col4" class="data row6 col4" >0.3192</td>
#       <td id="T_944b9_row6_col5" class="data row6 col5" >0.3096</td>
#       <td id="T_944b9_row6_col6" class="data row6 col6" >0.0833</td>
#       <td id="T_944b9_row6_col7" class="data row6 col7" >0.0843</td>
#       <td id="T_944b9_row6_col8" class="data row6 col8" >0.0367</td>
#     </tr>
#     <tr>
#       <th id="T_944b9_level0_row7" class="row_heading level0 row7" >svm</th>
#       <td id="T_944b9_row7_col0" class="data row7 col0" >
# <style type="text/css">
# </style>
# <table id="T_ea8e6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ea8e6_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ea8e6_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_ea8e6_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_ea8e6_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_ea8e6_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_ea8e6_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_ea8e6_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_ea8e6_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea8e6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ea8e6_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_ea8e6_row0_col1" class="data row0 col1" >0.1944</td>
#       <td id="T_ea8e6_row0_col2" class="data row0 col2" >0.5015</td>
#       <td id="T_ea8e6_row0_col3" class="data row0 col3" >0.1944</td>
#       <td id="T_ea8e6_row0_col4" class="data row0 col4" >0.2182</td>
#       <td id="T_ea8e6_row0_col5" class="data row0 col5" >0.2009</td>
#       <td id="T_ea8e6_row0_col6" class="data row0 col6" >-0.0741</td>
#       <td id="T_ea8e6_row0_col7" class="data row0 col7" >-0.0752</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_9eb65_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9eb65">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9eb65_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_9eb65_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9eb65_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9eb65_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_9eb65_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_9eb65_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9eb65_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_9eb65_row1_col1" class="data row1 col1" >domain_EI</td>
#     </tr>
#     <tr>
#       <th id="T_9eb65_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9eb65_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_9eb65_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_9eb65_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9eb65_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_9eb65_row3_col1" class="data row3 col1" >(180, 91)</td>
#     </tr>
#     <tr>
#       <th id="T_9eb65_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9eb65_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_9eb65_row4_col1" class="data row4 col1" >(180, 91)</td>
#     </tr>
#     <tr>
#       <th id="T_9eb65_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9eb65_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_9eb65_row5_col1" class="data row5 col1" >(144, 91)</td>
#     </tr>
#     <tr>
#       <th id="T_9eb65_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9eb65_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_9eb65_row6_col1" class="data row6 col1" >(36, 91)</td>
#     </tr>
#     <tr>
#       <th id="T_9eb65_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9eb65_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_9eb65_row7_col1" class="data row7 col1" >90</td>
#     </tr>
#     <tr>
#       <th id="T_9eb65_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9eb65_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_9eb65_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9eb65_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9eb65_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_9eb65_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_9eb65_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9eb65_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_9eb65_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_9eb65_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_9eb65_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_9eb65_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_9eb65_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_9eb65_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_9eb65_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_9eb65_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_9eb65_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_9eb65_row13_col1" class="data row13 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_9eb65_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_9eb65_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_9eb65_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_9eb65_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_9eb65_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_9eb65_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9eb65_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_9eb65_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_9eb65_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9eb65_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_9eb65_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_9eb65_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_9eb65_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_9eb65_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_9eb65_row18_col1" class="data row18 col1" >036d</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_62416 th {
#   text-align: left;
# }
# #T_62416_row0_col0, #T_62416_row0_col1, #T_62416_row0_col3, #T_62416_row0_col4, #T_62416_row0_col5, #T_62416_row0_col6, #T_62416_row0_col7, #T_62416_row1_col0, #T_62416_row1_col1, #T_62416_row1_col2, #T_62416_row1_col3, #T_62416_row1_col4, #T_62416_row1_col5, #T_62416_row1_col6, #T_62416_row1_col7, #T_62416_row2_col0, #T_62416_row2_col1, #T_62416_row2_col2, #T_62416_row2_col3, #T_62416_row2_col4, #T_62416_row2_col5, #T_62416_row2_col6, #T_62416_row2_col7, #T_62416_row3_col0, #T_62416_row3_col1, #T_62416_row3_col2, #T_62416_row3_col3, #T_62416_row3_col4, #T_62416_row3_col5, #T_62416_row3_col6, #T_62416_row3_col7, #T_62416_row4_col0, #T_62416_row4_col1, #T_62416_row4_col2, #T_62416_row4_col3, #T_62416_row4_col4, #T_62416_row4_col5, #T_62416_row4_col6, #T_62416_row4_col7, #T_62416_row5_col0, #T_62416_row5_col1, #T_62416_row5_col2, #T_62416_row5_col3, #T_62416_row5_col4, #T_62416_row5_col5, #T_62416_row5_col6, #T_62416_row5_col7, #T_62416_row6_col0, #T_62416_row6_col2, #T_62416_row7_col0, #T_62416_row7_col1, #T_62416_row7_col2, #T_62416_row7_col3, #T_62416_row7_col4, #T_62416_row7_col5, #T_62416_row7_col6, #T_62416_row7_col7, #T_62416_row8_col0, #T_62416_row8_col1, #T_62416_row8_col2, #T_62416_row8_col3, #T_62416_row8_col4, #T_62416_row8_col5, #T_62416_row8_col6, #T_62416_row8_col7 {
#   text-align: left;
# }
# #T_62416_row0_col2, #T_62416_row6_col1, #T_62416_row6_col3, #T_62416_row6_col4, #T_62416_row6_col5, #T_62416_row6_col6, #T_62416_row6_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_62416_row0_col8, #T_62416_row1_col8, #T_62416_row3_col8, #T_62416_row4_col8, #T_62416_row5_col8, #T_62416_row7_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_62416_row2_col8, #T_62416_row6_col8, #T_62416_row8_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_62416">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_62416_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_62416_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_62416_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_62416_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_62416_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_62416_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_62416_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_62416_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_62416_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_62416_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_62416_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_62416_row0_col1" class="data row0 col1" >0.2986</td>
#       <td id="T_62416_row0_col2" class="data row0 col2" >0.5181</td>
#       <td id="T_62416_row0_col3" class="data row0 col3" >0.2986</td>
#       <td id="T_62416_row0_col4" class="data row0 col4" >0.2949</td>
#       <td id="T_62416_row0_col5" class="data row0 col5" >0.2897</td>
#       <td id="T_62416_row0_col6" class="data row0 col6" >0.0648</td>
#       <td id="T_62416_row0_col7" class="data row0 col7" >0.0656</td>
#       <td id="T_62416_row0_col8" class="data row0 col8" >0.0400</td>
#     </tr>
#     <tr>
#       <th id="T_62416_level0_row1" class="row_heading level0 row1" >knn</th>
#       <td id="T_62416_row1_col0" class="data row1 col0" >K Neighbors Classifier</td>
#       <td id="T_62416_row1_col1" class="data row1 col1" >0.2500</td>
#       <td id="T_62416_row1_col2" class="data row1 col2" >0.5133</td>
#       <td id="T_62416_row1_col3" class="data row1 col3" >0.2500</td>
#       <td id="T_62416_row1_col4" class="data row1 col4" >0.2391</td>
#       <td id="T_62416_row1_col5" class="data row1 col5" >0.2270</td>
#       <td id="T_62416_row1_col6" class="data row1 col6" >0.0000</td>
#       <td id="T_62416_row1_col7" class="data row1 col7" >-0.0005</td>
#       <td id="T_62416_row1_col8" class="data row1 col8" >0.0133</td>
#     </tr>
#     <tr>
#       <th id="T_62416_level0_row2" class="row_heading level0 row2" >nb</th>
#       <td id="T_62416_row2_col0" class="data row2 col0" >Naive Bayes</td>
#       <td id="T_62416_row2_col1" class="data row2 col1" >0.2639</td>
#       <td id="T_62416_row2_col2" class="data row2 col2" >0.4914</td>
#       <td id="T_62416_row2_col3" class="data row2 col3" >0.2639</td>
#       <td id="T_62416_row2_col4" class="data row2 col4" >0.2697</td>
#       <td id="T_62416_row2_col5" class="data row2 col5" >0.2566</td>
#       <td id="T_62416_row2_col6" class="data row2 col6" >0.0185</td>
#       <td id="T_62416_row2_col7" class="data row2 col7" >0.0187</td>
#       <td id="T_62416_row2_col8" class="data row2 col8" >0.0067</td>
#     </tr>
#     <tr>
#       <th id="T_62416_level0_row3" class="row_heading level0 row3" >xgboost</th>
#       <td id="T_62416_row3_col0" class="data row3 col0" >Extreme Gradient Boosting</td>
#       <td id="T_62416_row3_col1" class="data row3 col1" >0.2014</td>
#       <td id="T_62416_row3_col2" class="data row3 col2" >0.4500</td>
#       <td id="T_62416_row3_col3" class="data row3 col3" >0.2014</td>
#       <td id="T_62416_row3_col4" class="data row3 col4" >0.1848</td>
#       <td id="T_62416_row3_col5" class="data row3 col5" >0.1887</td>
#       <td id="T_62416_row3_col6" class="data row3 col6" >-0.0648</td>
#       <td id="T_62416_row3_col7" class="data row3 col7" >-0.0667</td>
#       <td id="T_62416_row3_col8" class="data row3 col8" >0.1533</td>
#     </tr>
#     <tr>
#       <th id="T_62416_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_62416_row4_col0" class="data row4 col0" >Random Forest Classifier</td>
#       <td id="T_62416_row4_col1" class="data row4 col1" >0.1944</td>
#       <td id="T_62416_row4_col2" class="data row4 col2" >0.4422</td>
#       <td id="T_62416_row4_col3" class="data row4 col3" >0.1944</td>
#       <td id="T_62416_row4_col4" class="data row4 col4" >0.1975</td>
#       <td id="T_62416_row4_col5" class="data row4 col5" >0.1939</td>
#       <td id="T_62416_row4_col6" class="data row4 col6" >-0.0741</td>
#       <td id="T_62416_row4_col7" class="data row4 col7" >-0.0749</td>
#       <td id="T_62416_row4_col8" class="data row4 col8" >0.0467</td>
#     </tr>
#     <tr>
#       <th id="T_62416_level0_row5" class="row_heading level0 row5" >catboost</th>
#       <td id="T_62416_row5_col0" class="data row5 col0" >CatBoost Classifier</td>
#       <td id="T_62416_row5_col1" class="data row5 col1" >0.1944</td>
#       <td id="T_62416_row5_col2" class="data row5 col2" >0.4228</td>
#       <td id="T_62416_row5_col3" class="data row5 col3" >0.1944</td>
#       <td id="T_62416_row5_col4" class="data row5 col4" >0.1887</td>
#       <td id="T_62416_row5_col5" class="data row5 col5" >0.1888</td>
#       <td id="T_62416_row5_col6" class="data row5 col6" >-0.0741</td>
#       <td id="T_62416_row5_col7" class="data row5 col7" >-0.0745</td>
#       <td id="T_62416_row5_col8" class="data row5 col8" >2.3233</td>
#     </tr>
#     <tr>
#       <th id="T_62416_level0_row6" class="row_heading level0 row6" >lr</th>
#       <td id="T_62416_row6_col0" class="data row6 col0" >Logistic Regression</td>
#       <td id="T_62416_row6_col1" class="data row6 col1" >0.3611</td>
#       <td id="T_62416_row6_col2" class="data row6 col2" >0.0000</td>
#       <td id="T_62416_row6_col3" class="data row6 col3" >0.3611</td>
#       <td id="T_62416_row6_col4" class="data row6 col4" >0.3630</td>
#       <td id="T_62416_row6_col5" class="data row6 col5" >0.3574</td>
#       <td id="T_62416_row6_col6" class="data row6 col6" >0.1481</td>
#       <td id="T_62416_row6_col7" class="data row6 col7" >0.1491</td>
#       <td id="T_62416_row6_col8" class="data row6 col8" >0.0067</td>
#     </tr>
#     <tr>
#       <th id="T_62416_level0_row7" class="row_heading level0 row7" >svm</th>
#       <td id="T_62416_row7_col0" class="data row7 col0" >S
# <style type="text/css">
# </style>
# <table id="T_c1920">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c1920_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c1920_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_c1920_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_c1920_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_c1920_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_c1920_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_c1920_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_c1920_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c1920_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c1920_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_c1920_row0_col1" class="data row0 col1" >0.2222</td>
#       <td id="T_c1920_row0_col2" class="data row0 col2" >0.4907</td>
#       <td id="T_c1920_row0_col3" class="data row0 col3" >0.2222</td>
#       <td id="T_c1920_row0_col4" class="data row0 col4" >0.2419</td>
#       <td id="T_c1920_row0_col5" class="data row0 col5" >0.2268</td>
#       <td id="T_c1920_row0_col6" class="data row0 col6" >-0.0370</td>
#       <td id="T_c1920_row0_col7" class="data row0 col7" >-0.0375</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_942d2_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_942d2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_942d2_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_942d2_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_942d2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_942d2_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_942d2_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_942d2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_942d2_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_942d2_row1_col1" class="data row1 col1" >domain_EI</td>
#     </tr>
#     <tr>
#       <th id="T_942d2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_942d2_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_942d2_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_942d2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_942d2_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_942d2_row3_col1" class="data row3 col1" >(180, 91)</td>
#     </tr>
#     <tr>
#       <th id="T_942d2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_942d2_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_942d2_row4_col1" class="data row4 col1" >(180, 91)</td>
#     </tr>
#     <tr>
#       <th id="T_942d2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_942d2_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_942d2_row5_col1" class="data row5 col1" >(144, 91)</td>
#     </tr>
#     <tr>
#       <th id="T_942d2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_942d2_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_942d2_row6_col1" class="data row6 col1" >(36, 91)</td>
#     </tr>
#     <tr>
#       <th id="T_942d2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_942d2_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_942d2_row7_col1" class="data row7 col1" >90</td>
#     </tr>
#     <tr>
#       <th id="T_942d2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_942d2_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_942d2_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_942d2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_942d2_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_942d2_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_942d2_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_942d2_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_942d2_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_942d2_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_942d2_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_942d2_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_942d2_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_942d2_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_942d2_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_942d2_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_942d2_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_942d2_row13_col1" class="data row13 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_942d2_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_942d2_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_942d2_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_942d2_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_942d2_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_942d2_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_942d2_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_942d2_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_942d2_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_942d2_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_942d2_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_942d2_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_942d2_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_942d2_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_942d2_row18_col1" class="data row18 col1" >d7dd</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_7a40b th {
#   text-align: left;
# }
# #T_7a40b_row0_col0, #T_7a40b_row0_col1, #T_7a40b_row0_col3, #T_7a40b_row0_col4, #T_7a40b_row0_col5, #T_7a40b_row0_col6, #T_7a40b_row0_col7, #T_7a40b_row1_col0, #T_7a40b_row1_col1, #T_7a40b_row1_col2, #T_7a40b_row1_col3, #T_7a40b_row1_col4, #T_7a40b_row1_col5, #T_7a40b_row1_col6, #T_7a40b_row1_col7, #T_7a40b_row2_col0, #T_7a40b_row2_col1, #T_7a40b_row2_col2, #T_7a40b_row2_col3, #T_7a40b_row2_col4, #T_7a40b_row2_col5, #T_7a40b_row2_col6, #T_7a40b_row2_col7, #T_7a40b_row3_col0, #T_7a40b_row3_col1, #T_7a40b_row3_col2, #T_7a40b_row3_col3, #T_7a40b_row3_col4, #T_7a40b_row3_col5, #T_7a40b_row3_col6, #T_7a40b_row3_col7, #T_7a40b_row4_col0, #T_7a40b_row4_col1, #T_7a40b_row4_col2, #T_7a40b_row4_col3, #T_7a40b_row4_col4, #T_7a40b_row4_col5, #T_7a40b_row4_col6, #T_7a40b_row4_col7, #T_7a40b_row5_col0, #T_7a40b_row5_col1, #T_7a40b_row5_col2, #T_7a40b_row5_col3, #T_7a40b_row5_col4, #T_7a40b_row5_col5, #T_7a40b_row5_col6, #T_7a40b_row5_col7, #T_7a40b_row6_col0, #T_7a40b_row6_col2, #T_7a40b_row6_col4, #T_7a40b_row7_col0, #T_7a40b_row7_col1, #T_7a40b_row7_col2, #T_7a40b_row7_col3, #T_7a40b_row7_col5, #T_7a40b_row7_col6, #T_7a40b_row7_col7, #T_7a40b_row8_col0, #T_7a40b_row8_col1, #T_7a40b_row8_col2, #T_7a40b_row8_col3, #T_7a40b_row8_col4, #T_7a40b_row8_col5, #T_7a40b_row8_col6, #T_7a40b_row8_col7 {
#   text-align: left;
# }
# #T_7a40b_row0_col2, #T_7a40b_row6_col1, #T_7a40b_row6_col3, #T_7a40b_row6_col5, #T_7a40b_row6_col6, #T_7a40b_row6_col7, #T_7a40b_row7_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_7a40b_row0_col8, #T_7a40b_row1_col8, #T_7a40b_row3_col8, #T_7a40b_row4_col8, #T_7a40b_row5_col8, #T_7a40b_row6_col8, #T_7a40b_row7_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_7a40b_row2_col8, #T_7a40b_row8_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_7a40b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7a40b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7a40b_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_7a40b_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_7a40b_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_7a40b_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_7a40b_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_7a40b_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_7a40b_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_7a40b_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a40b_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_7a40b_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_7a40b_row0_col1" class="data row0 col1" >0.2708</td>
#       <td id="T_7a40b_row0_col2" class="data row0 col2" >0.5239</td>
#       <td id="T_7a40b_row0_col3" class="data row0 col3" >0.2708</td>
#       <td id="T_7a40b_row0_col4" class="data row0 col4" >0.2629</td>
#       <td id="T_7a40b_row0_col5" class="data row0 col5" >0.2593</td>
#       <td id="T_7a40b_row0_col6" class="data row0 col6" >0.0278</td>
#       <td id="T_7a40b_row0_col7" class="data row0 col7" >0.0285</td>
#       <td id="T_7a40b_row0_col8" class="data row0 col8" >0.0433</td>
#     </tr>
#     <tr>
#       <th id="T_7a40b_level0_row1" class="row_heading level0 row1" >knn</th>
#       <td id="T_7a40b_row1_col0" class="data row1 col0" >K Neighbors Classifier</td>
#       <td id="T_7a40b_row1_col1" class="data row1 col1" >0.2431</td>
#       <td id="T_7a40b_row1_col2" class="data row1 col2" >0.5160</td>
#       <td id="T_7a40b_row1_col3" class="data row1 col3" >0.2431</td>
#       <td id="T_7a40b_row1_col4" class="data row1 col4" >0.2593</td>
#       <td id="T_7a40b_row1_col5" class="data row1 col5" >0.2446</td>
#       <td id="T_7a40b_row1_col6" class="data row1 col6" >-0.0093</td>
#       <td id="T_7a40b_row1_col7" class="data row1 col7" >-0.0106</td>
#       <td id="T_7a40b_row1_col8" class="data row1 col8" >0.0133</td>
#     </tr>
#     <tr>
#       <th id="T_7a40b_level0_row2" class="row_heading level0 row2" >nb</th>
#       <td id="T_7a40b_row2_col0" class="data row2 col0" >Naive Bayes</td>
#       <td id="T_7a40b_row2_col1" class="data row2 col1" >0.2639</td>
#       <td id="T_7a40b_row2_col2" class="data row2 col2" >0.4914</td>
#       <td id="T_7a40b_row2_col3" class="data row2 col3" >0.2639</td>
#       <td id="T_7a40b_row2_col4" class="data row2 col4" >0.2697</td>
#       <td id="T_7a40b_row2_col5" class="data row2 col5" >0.2566</td>
#       <td id="T_7a40b_row2_col6" class="data row2 col6" >0.0185</td>
#       <td id="T_7a40b_row2_col7" class="data row2 col7" >0.0187</td>
#       <td id="T_7a40b_row2_col8" class="data row2 col8" >0.0067</td>
#     </tr>
#     <tr>
#       <th id="T_7a40b_level0_row3" class="row_heading level0 row3" >xgboost</th>
#       <td id="T_7a40b_row3_col0" class="data row3 col0" >Extreme Gradient Boosting</td>
#       <td id="T_7a40b_row3_col1" class="data row3 col1" >0.2222</td>
#       <td id="T_7a40b_row3_col2" class="data row3 col2" >0.4481</td>
#       <td id="T_7a40b_row3_col3" class="data row3 col3" >0.2222</td>
#       <td id="T_7a40b_row3_col4" class="data row3 col4" >0.2085</td>
#       <td id="T_7a40b_row3_col5" class="data row3 col5" >0.2098</td>
#       <td id="T_7a40b_row3_col6" class="data row3 col6" >-0.0370</td>
#       <td id="T_7a40b_row3_col7" class="data row3 col7" >-0.0389</td>
#       <td id="T_7a40b_row3_col8" class="data row3 col8" >0.1500</td>
#     </tr>
#     <tr>
#       <th id="T_7a40b_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_7a40b_row4_col0" class="data row4 col0" >Random Forest Classifier</td>
#       <td id="T_7a40b_row4_col1" class="data row4 col1" >0.2014</td>
#       <td id="T_7a40b_row4_col2" class="data row4 col2" >0.4470</td>
#       <td id="T_7a40b_row4_col3" class="data row4 col3" >0.2014</td>
#       <td id="T_7a40b_row4_col4" class="data row4 col4" >0.2024</td>
#       <td id="T_7a40b_row4_col5" class="data row4 col5" >0.1999</td>
#       <td id="T_7a40b_row4_col6" class="data row4 col6" >-0.0648</td>
#       <td id="T_7a40b_row4_col7" class="data row4 col7" >-0.0656</td>
#       <td id="T_7a40b_row4_col8" class="data row4 col8" >0.0500</td>
#     </tr>
#     <tr>
#       <th id="T_7a40b_level0_row5" class="row_heading level0 row5" >catboost</th>
#       <td id="T_7a40b_row5_col0" class="data row5 col0" >CatBoost Classifier</td>
#       <td id="T_7a40b_row5_col1" class="data row5 col1" >0.2222</td>
#       <td id="T_7a40b_row5_col2" class="data row5 col2" >0.4385</td>
#       <td id="T_7a40b_row5_col3" class="data row5 col3" >0.2222</td>
#       <td id="T_7a40b_row5_col4" class="data row5 col4" >0.2190</td>
#       <td id="T_7a40b_row5_col5" class="data row5 col5" >0.2158</td>
#       <td id="T_7a40b_row5_col6" class="data row5 col6" >-0.0370</td>
#       <td id="T_7a40b_row5_col7" class="data row5 col7" >-0.0369</td>
#       <td id="T_7a40b_row5_col8" class="data row5 col8" >2.3400</td>
#     </tr>
#     <tr>
#       <th id="T_7a40b_level0_row6" class="row_heading level0 row6" >lr</th>
#       <td id="T_7a40b_row6_col0" class="data row6 col0" >Logistic Regression</td>
#       <td id="T_7a40b_row6_col1" class="data row6 col1" >0.3056</td>
#       <td id="T_7a40b_row6_col2" class="data row6 col2" >0.0000</td>
#       <td id="T_7a40b_row6_col3" class="data row6 col3" >0.3056</td>
#       <td id="T_7a40b_row6_col4" class="data row6 col4" >0.3134</td>
#       <td id="T_7a40b_row6_col5" class="data row6 col5" >0.3043</td>
#       <td id="T_7a40b_row6_col6" class="data row6 col6" >0.0741</td>
#       <td id="T_7a40b_row6_col7" class="data row6 col7" >0.0750</td>
#       <td id="T_7a40b_row6_col8" class="data row6 col8" >0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_7a40b_level0_row7" class="row_heading level0 row7" >svm</th>
#       <td id="T_7a40b_row7_col0" class="data row7 col0" >
# <style type="text/css">
# </style>
# <table id="T_5cffc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5cffc_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_5cffc_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_5cffc_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_5cffc_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_5cffc_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_5cffc_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_5cffc_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_5cffc_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5cffc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5cffc_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_5cffc_row0_col1" class="data row0 col1" >0.2222</td>
#       <td id="T_5cffc_row0_col2" class="data row0 col2" >0.4856</td>
#       <td id="T_5cffc_row0_col3" class="data row0 col3" >0.2222</td>
#       <td id="T_5cffc_row0_col4" class="data row0 col4" >0.2506</td>
#       <td id="T_5cffc_row0_col5" class="data row0 col5" >0.2288</td>
#       <td id="T_5cffc_row0_col6" class="data row0 col6" >-0.0370</td>
#       <td id="T_5cffc_row0_col7" class="data row0 col7" >-0.0378</td>
#     </tr>
#   </tbody>
# </table>
# Feature Configs:  25%|██▌       | 1/4 [00:32<01:36, 32.24s/it]
# <style type="text/css">
# #T_2c2af_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2c2af">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2c2af_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_2c2af_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2c2af_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2c2af_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_2c2af_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_2c2af_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2c2af_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_2c2af_row1_col1" class="data row1 col1" >domain_EI</td>
#     </tr>
#     <tr>
#       <th id="T_2c2af_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2c2af_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_2c2af_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_2c2af_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2c2af_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_2c2af_row3_col1" class="data row3 col1" >(180, 90)</td>
#     </tr>
#     <tr>
#       <th id="T_2c2af_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2c2af_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_2c2af_row4_col1" class="data row4 col1" >(180, 90)</td>
#     </tr>
#     <tr>
#       <th id="T_2c2af_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2c2af_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_2c2af_row5_col1" class="data row5 col1" >(144, 90)</td>
#     </tr>
#     <tr>
#       <th id="T_2c2af_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2c2af_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_2c2af_row6_col1" class="data row6 col1" >(36, 90)</td>
#     </tr>
#     <tr>
#       <th id="T_2c2af_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2c2af_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_2c2af_row7_col1" class="data row7 col1" >89</td>
#     </tr>
#     <tr>
#       <th id="T_2c2af_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2c2af_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_2c2af_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2c2af_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2c2af_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_2c2af_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_2c2af_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_2c2af_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_2c2af_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_2c2af_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_2c2af_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_2c2af_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_2c2af_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_2c2af_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_2c2af_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_2c2af_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_2c2af_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_2c2af_row13_col1" class="data row13 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_2c2af_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_2c2af_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_2c2af_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_2c2af_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_2c2af_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_2c2af_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2c2af_level0_row16" class="row_heading level0 row16" >16</th>
# ...
# </style>
# <table id="T_7f342">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7f342_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7f342_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_7f342_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_7f342_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_7f342_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_7f342_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_7f342_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_7f342_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f342_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7f342_row0_col0" class="data row0 col0" >K Neighbors Classifier</td>
#       <td id="T_7f342_row0_col1" class="data row0 col1" >0.2222</td>
#       <td id="T_7f342_row0_col2" class="data row0 col2" >0.5442</td>
#       <td id="T_7f342_row0_col3" class="data row0 col3" >0.2222</td>
#       <td id="T_7f342_row0_col4" class="data row0 col4" >0.2143</td>
#       <td id="T_7f342_row0_col5" class="data row0 col5" >0.1875</td>
#       <td id="T_7f342_row0_col6" class="data row0 col6" >-0.0370</td>
#       <td id="T_7f342_row0_col7" class="data row0 col7" >-0.0416</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_a4394_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a4394">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a4394_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_a4394_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a4394_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a4394_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_a4394_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_a4394_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a4394_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a4394_row1_col1" class="data row1 col1" >domain_EI</td>
#     </tr>
#     <tr>
#       <th id="T_a4394_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a4394_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_a4394_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_a4394_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a4394_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_a4394_row3_col1" class="data row3 col1" >(180, 89)</td>
#     </tr>
#     <tr>
#       <th id="T_a4394_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a4394_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_a4394_row4_col1" class="data row4 col1" >(180, 89)</td>
#     </tr>
#     <tr>
#       <th id="T_a4394_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a4394_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_a4394_row5_col1" class="data row5 col1" >(144, 89)</td>
#     </tr>
#     <tr>
#       <th id="T_a4394_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a4394_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_a4394_row6_col1" class="data row6 col1" >(36, 89)</td>
#     </tr>
#     <tr>
#       <th id="T_a4394_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a4394_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_a4394_row7_col1" class="data row7 col1" >88</td>
#     </tr>
#     <tr>
#       <th id="T_a4394_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a4394_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_a4394_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a4394_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a4394_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_a4394_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_a4394_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a4394_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_a4394_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_a4394_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a4394_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_a4394_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_a4394_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a4394_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_a4394_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_a4394_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a4394_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_a4394_row13_col1" class="data row13 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_a4394_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a4394_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_a4394_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_a4394_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a4394_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_a4394_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a4394_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_a4394_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_a4394_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a4394_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_a4394_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_a4394_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_a4394_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_a4394_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_a4394_row18_col1" class="data row18 col1" >528e</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_7047a th {
#   text-align: left;
# }
# #T_7047a_row0_col0, #T_7047a_row0_col1, #T_7047a_row0_col3, #T_7047a_row0_col4, #T_7047a_row0_col5, #T_7047a_row0_col6, #T_7047a_row0_col7, #T_7047a_row1_col0, #T_7047a_row1_col1, #T_7047a_row1_col2, #T_7047a_row1_col3, #T_7047a_row1_col4, #T_7047a_row1_col5, #T_7047a_row1_col6, #T_7047a_row1_col7, #T_7047a_row2_col0, #T_7047a_row2_col1, #T_7047a_row2_col2, #T_7047a_row2_col3, #T_7047a_row2_col4, #T_7047a_row2_col5, #T_7047a_row2_col6, #T_7047a_row2_col7, #T_7047a_row3_col0, #T_7047a_row3_col1, #T_7047a_row3_col2, #T_7047a_row3_col3, #T_7047a_row3_col4, #T_7047a_row3_col5, #T_7047a_row3_col6, #T_7047a_row3_col7, #T_7047a_row4_col0, #T_7047a_row4_col1, #T_7047a_row4_col2, #T_7047a_row4_col3, #T_7047a_row4_col4, #T_7047a_row4_col5, #T_7047a_row4_col6, #T_7047a_row4_col7, #T_7047a_row5_col0, #T_7047a_row5_col1, #T_7047a_row5_col2, #T_7047a_row5_col3, #T_7047a_row5_col4, #T_7047a_row5_col5, #T_7047a_row5_col6, #T_7047a_row5_col7, #T_7047a_row6_col0, #T_7047a_row6_col2, #T_7047a_row7_col0, #T_7047a_row7_col1, #T_7047a_row7_col2, #T_7047a_row7_col3, #T_7047a_row7_col4, #T_7047a_row7_col5, #T_7047a_row7_col6, #T_7047a_row7_col7, #T_7047a_row8_col0, #T_7047a_row8_col1, #T_7047a_row8_col2, #T_7047a_row8_col3, #T_7047a_row8_col4, #T_7047a_row8_col5, #T_7047a_row8_col6, #T_7047a_row8_col7 {
#   text-align: left;
# }
# #T_7047a_row0_col2, #T_7047a_row6_col1, #T_7047a_row6_col3, #T_7047a_row6_col4, #T_7047a_row6_col5, #T_7047a_row6_col6, #T_7047a_row6_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_7047a_row0_col8, #T_7047a_row2_col8, #T_7047a_row3_col8, #T_7047a_row4_col8, #T_7047a_row5_col8, #T_7047a_row6_col8, #T_7047a_row7_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_7047a_row1_col8, #T_7047a_row8_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_7047a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7047a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7047a_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_7047a_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_7047a_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_7047a_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_7047a_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_7047a_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_7047a_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_7047a_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7047a_level0_row0" class="row_heading level0 row0" >knn</th>
#       <td id="T_7047a_row0_col0" class="data row0 col0" >K Neighbors Classifier</td>
#       <td id="T_7047a_row0_col1" class="data row0 col1" >0.2778</td>
#       <td id="T_7047a_row0_col2" class="data row0 col2" >0.5268</td>
#       <td id="T_7047a_row0_col3" class="data row0 col3" >0.2778</td>
#       <td id="T_7047a_row0_col4" class="data row0 col4" >0.2841</td>
#       <td id="T_7047a_row0_col5" class="data row0 col5" >0.2598</td>
#       <td id="T_7047a_row0_col6" class="data row0 col6" >0.0370</td>
#       <td id="T_7047a_row0_col7" class="data row0 col7" >0.0390</td>
#       <td id="T_7047a_row0_col8" class="data row0 col8" >0.0133</td>
#     </tr>
#     <tr>
#       <th id="T_7047a_level0_row1" class="row_heading level0 row1" >nb</th>
#       <td id="T_7047a_row1_col0" class="data row1 col0" >Naive Bayes</td>
#       <td id="T_7047a_row1_col1" class="data row1 col1" >0.2708</td>
#       <td id="T_7047a_row1_col2" class="data row1 col2" >0.4930</td>
#       <td id="T_7047a_row1_col3" class="data row1 col3" >0.2708</td>
#       <td id="T_7047a_row1_col4" class="data row1 col4" >0.2744</td>
#       <td id="T_7047a_row1_col5" class="data row1 col5" >0.2635</td>
#       <td id="T_7047a_row1_col6" class="data row1 col6" >0.0278</td>
#       <td id="T_7047a_row1_col7" class="data row1 col7" >0.0276</td>
#       <td id="T_7047a_row1_col8" class="data row1 col8" >0.0067</td>
#     </tr>
#     <tr>
#       <th id="T_7047a_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_7047a_row2_col0" class="data row2 col0" >Extra Trees Classifier</td>
#       <td id="T_7047a_row2_col1" class="data row2 col1" >0.2014</td>
#       <td id="T_7047a_row2_col2" class="data row2 col2" >0.4848</td>
#       <td id="T_7047a_row2_col3" class="data row2 col3" >0.2014</td>
#       <td id="T_7047a_row2_col4" class="data row2 col4" >0.1937</td>
#       <td id="T_7047a_row2_col5" class="data row2 col5" >0.1943</td>
#       <td id="T_7047a_row2_col6" class="data row2 col6" >-0.0648</td>
#       <td id="T_7047a_row2_col7" class="data row2 col7" >-0.0656</td>
#       <td id="T_7047a_row2_col8" class="data row2 col8" >0.0400</td>
#     </tr>
#     <tr>
#       <th id="T_7047a_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_7047a_row3_col0" class="data row3 col0" >Random Forest Classifier</td>
#       <td id="T_7047a_row3_col1" class="data row3 col1" >0.2431</td>
#       <td id="T_7047a_row3_col2" class="data row3 col2" >0.4629</td>
#       <td id="T_7047a_row3_col3" class="data row3 col3" >0.2431</td>
#       <td id="T_7047a_row3_col4" class="data row3 col4" >0.2412</td>
#       <td id="T_7047a_row3_col5" class="data row3 col5" >0.2397</td>
#       <td id="T_7047a_row3_col6" class="data row3 col6" >-0.0093</td>
#       <td id="T_7047a_row3_col7" class="data row3 col7" >-0.0097</td>
#       <td id="T_7047a_row3_col8" class="data row3 col8" >0.0500</td>
#     </tr>
#     <tr>
#       <th id="T_7047a_level0_row4" class="row_heading level0 row4" >xgboost</th>
#       <td id="T_7047a_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#       <td id="T_7047a_row4_col1" class="data row4 col1" >0.2292</td>
#       <td id="T_7047a_row4_col2" class="data row4 col2" >0.4394</td>
#       <td id="T_7047a_row4_col3" class="data row4 col3" >0.2292</td>
#       <td id="T_7047a_row4_col4" class="data row4 col4" >0.2305</td>
#       <td id="T_7047a_row4_col5" class="data row4 col5" >0.2263</td>
#       <td id="T_7047a_row4_col6" class="data row4 col6" >-0.0278</td>
#       <td id="T_7047a_row4_col7" class="data row4 col7" >-0.0287</td>
#       <td id="T_7047a_row4_col8" class="data row4 col8" >0.1200</td>
#     </tr>
#     <tr>
#       <th id="T_7047a_level0_row5" class="row_heading level0 row5" >catboost</th>
#       <td id="T_7047a_row5_col0" class="data row5 col0" >CatBoost Classifier</td>
#       <td id="T_7047a_row5_col1" class="data row5 col1" >0.2153</td>
#       <td id="T_7047a_row5_col2" class="data row5 col2" >0.4361</td>
#       <td id="T_7047a_row5_col3" class="data row5 col3" >0.2153</td>
#       <td id="T_7047a_row5_col4" class="data row5 col4" >0.2077</td>
#       <td id="T_7047a_row5_col5" class="data row5 col5" >0.2066</td>
#       <td id="T_7047a_row5_col6" class="data row5 col6" >-0.0463</td>
#       <td id="T_7047a_row5_col7" class="data row5 col7" >-0.0471</td>
#       <td id="T_7047a_row5_col8" class="data row5 col8" >2.2833</td>
#     </tr>
#     <tr>
#       <th id="T_7047a_level0_row6" class="row_heading level0 row6" >lr</th>
#       <td id="T_7047a_row6_col0" class="data row6 col0" >Logistic Regression</td>
#       <td id="T_7047a_row6_col1" class="data row6 col1" >0.3264</td>
#       <td id="T_7047a_row6_col2" class="data row6 col2" >0.0000</td>
#       <td id="T_7047a_row6_col3" class="data row6 col3" >0.3264</td>
#       <td id="T_7047a_row6_col4" class="data row6 col4" >0.3468</td>
#       <td id="T_7047a_row6_col5" class="data row6 col5" >0.3285</td>
#       <td id="T_7047a_row6_col6" class="data row6 col6" >0.1019</td>
#       <td id="T_7047a_row6_col7" class="data row6 col7" >0.1033</td>
#       <td id="T_7047a_row6_col8" class="data row6 col8" >0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_7047a_level0_row7" class="row_heading level0 row7" >svm</th>
#       <td id="T_7047a_row7_col0" class="data row7 col0" >
# <style type="text/css">
# </style>
# <table id="T_67137">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_67137_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_67137_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_67137_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_67137_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_67137_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_67137_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_67137_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_67137_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_67137_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_67137_row0_col0" class="data row0 col0" >K Neighbors Classifier</td>
#       <td id="T_67137_row0_col1" class="data row0 col1" >0.2222</td>
#       <td id="T_67137_row0_col2" class="data row0 col2" >0.5118</td>
#       <td id="T_67137_row0_col3" class="data row0 col3" >0.2222</td>
#       <td id="T_67137_row0_col4" class="data row0 col4" >0.3345</td>
#       <td id="T_67137_row0_col5" class="data row0 col5" >0.2006</td>
#       <td id="T_67137_row0_col6" class="data row0 col6" >-0.0370</td>
#       <td id="T_67137_row0_col7" class="data row0 col7" >-0.0424</td>
#     </tr>
#   </tbody>
# </table>
# Feature Configs: 100%|██████████| 4/4 [02:05<00:00, 31.33s/it]

# %% [markdown]
# ## Step 4. Save overall summary

# %%
results_df = pd.DataFrame(results)
results_df.to_csv("overall_results.csv", index=False)

# %% [markdown]
# ## 🎯 Selective Outlier Removal Based on XGBoost Feature Importance
#
# Instead of removing all outliers across 88 features, we focus only on the top 10 features identified as most influential for classifying `domain_EI` using XGBoost.
#
# ### Method
#
# - Extract top 10 features with highest importance scores.
# - Apply Z-score based outlier detection (`|Z| > 4`) on those features only.
# - Remove rows where extreme values are detected in these features.
# - Visualize before/after distributions to confirm effective filtering.
#
# This approach ensures:
# - High-impact errors are removed.
# - Valuable data is preserved from non-influential features.

# %%
'''# Step1: Important Features
important_features = [
    'HF', 'lnLF', 'RSA_var', 'LFp_var', 'lnVLF_mssd',
    'HF_var', 'VLFp_mssd', 'rMSSD_autocorr', 'dHz_mssd', 'BPM_autocorr'
]
'''

# %%
'''# Step 2. Z-score calculation (Top-10 Imporatant features only) and Z > 4 row detection
z_scores = df[important_features].apply(zscore)

extreme_mask = (np.abs(z_scores) > 4).any(axis=1)
df_outliers = df[extreme_mask]
df_cleaned = df[~extreme_mask].copy()

# Step 3. Remove outliers from the original DataFrame
print(f"⚠️ Rows with Z > 4 in important features: {extreme_mask.sum()} / {len(df)}")
print("Exclude row's name + index:")
display(df_outliers[['name']].reset_index())

print(f"✅ Cleaned data shape: {df_cleaned.shape}")
'''

# %%
'''# Step 4. Plotting the distribution of important features before and after removing outliers
df_before = df[important_features].copy()
df_before['source'] = 'Before'

df_after = df_cleaned[important_features].copy()
df_after['source'] = 'After'

df_plot = pd.concat([df_before, df_after])
df_plot = df_plot.melt(id_vars='source', var_name='feature', value_name='value')

plt.figure(figsize=(20,15))
sns.boxplot(data=df_plot, x='feature', y='value', hue='source')
plt.title("Top Features Distribution: Before vs After Z > 4 Removal")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()'''
